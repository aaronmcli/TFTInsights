# %%
units = [
    {"name": "Alistar",    "origins": ["Golden Ox"],       "classes": ["Bruiser"],           "image": "img/Alistar.jpg"},
    {"name": "Annie",      "origins": ["Golden Ox"],       "classes": ["A.M.P."],            "image": "img/Annie.jpg"},
    {"name": "Aphelios",   "origins": ["Golden Ox"],       "classes": ["Marksman"],          "image": "img/Aphelios.jpg"},
    {"name": "Aurora",     "origins": ["Anima Squad"],     "classes": ["Dynamo"],            "image": "img/Aurora.jpg"},
    {"name": "Brand",      "origins": ["Street Demon"],    "classes": ["Techie"],            "image": "img/Brand.jpg"},
    {"name": "Braum",      "origins": ["Syndicate"],      "classes": ["Vanguard"],          "image": "img/Braum.jpg"},
    {"name": "Cho'Gath",   "origins": ["BoomBots"],       "classes": ["Bruiser"],           "image": "img/Cho'Gath.jpg"},
    {"name": "Darius",     "origins": ["Syndicate"],      "classes": ["Bruiser"],           "image": "img/Darius.jpg"},
    {"name": "Draven",     "origins": ["Cypher"],         "classes": ["Rapidfire"],         "image": "img/Draven.jpg"},
    {"name": "Dr. Mundo",  "origins": ["Street Demon"],    "classes": ["Bruiser", "Slayer"], "image": "img/Dr. Mundo.jpg"},
    {"name": "Ekko",       "origins": ["Street Demon"],    "classes": ["Strategist"],        "image": "img/Ekko.jpg"},
    {"name": "Elise",      "origins": ["Nitro"],          "classes": ["Dynamo"],            "image": "img/Elise.jpg"},
    {"name": "Fiddlesticks","origins": ["BoomBots"],      "classes": ["Techie"],            "image": "img/Fiddlesticks.jpg"},
    {"name": "Galio",      "origins": ["Cypher"],         "classes": ["Bastion"],           "image": "img/Galio.jpg"},
    {"name": "Garen",      "origins": ["God of the Net"], "classes": [],                   "image": "img/Garen.jpg"},
    {"name": "Gragas",     "origins": ["Divinicorp"],     "classes": ["Bruiser"],           "image": "img/Gragas.jpg"},
    {"name": "Graves",     "origins": ["Golden Ox"],       "classes": ["Executioner"],       "image": "img/Graves.jpg"},
    {"name": "Illaoi",     "origins": ["Anima Squad"],     "classes": ["Bastion"],           "image": "img/Illaoi.jpg"},
    {"name": "Jarvan IV",  "origins": ["Golden Ox"],       "classes": ["Vanguard", "Slayer"],"image": "img/Jarvan IV.jpg"},
    {"name": "Jax",        "origins": ["Exotech"],        "classes": ["Bastion"],           "image": "img/Jax.jpg"},
    {"name": "Jhin",       "origins": ["Exotech"],        "classes": ["Marksman", "Dynamo"],"image": "img/Jhin.jpg"},
    {"name": "Jinx",       "origins": ["Street Demon"],    "classes": ["Marksman"],          "image": "img/Jinx.jpg"},
    {"name": "Kindred",    "origins": ["Nitro"],          "classes": ["Rapidfire", "Marksman"], "image": "img/Kindred.jpg"},
    {"name": "Kobuko",     "origins": ["Cyberboss"],      "classes": ["Bruiser"],           "image": "img/Kobuko.jpg"},
    {"name": "Kog'Maw",    "origins": ["BoomBots"],       "classes": ["Rapidfire"],         "image": "img/Kog'Maw.jpg"},
    {"name": "LeBlanc",    "origins": ["Cypher"],         "classes": ["Strategist"],        "image": "img/LeBlanc.jpg"},
    {"name": "Leona",      "origins": ["Anima Squad"],     "classes": ["Vanguard"],          "image": "img/Leona.jpg"},
    {"name": "Miss Fortune","origins": ["Syndicate"],     "classes": ["Dynamo"],            "image": "img/Miss Fortune.jpg"},
    {"name": "Mordekaiser","origins": ["Exotech"],        "classes": ["Bruiser", "Techie"], "image": "img/Mordekaiser.jpg"},
    {"name": "Morgana",    "origins": ["Divinicorp"],     "classes": ["Dynamo"],            "image": "img/Morgana.jpg"},
    {"name": "Naafiri",    "origins": ["Exotech"],        "classes": ["A.M.P."],            "image": "img/Naafiri.jpg"},
    {"name": "Neeko",      "origins": ["Street Demon"],    "classes": ["Strategist"],        "image": "img/Neeko.jpg"},
    {"name": "Nidalee",    "origins": ["Nitro"],          "classes": ["A.M.P."],            "image": "img/Nidalee.jpg"},
    {"name": "Poppy",      "origins": ["Cyberboss"],      "classes": ["Bastion"],           "image": "img/Poppy.jpg"},
    {"name": "Renekton",   "origins": ["Overlord", "Divinicorp"], "classes": ["Bastion"],    "image": "img/Renekton.jpg"},
    {"name": "Rengar",     "origins": ["Street Demon"],    "classes": ["Executioner"],       "image": "img/Rengar.jpg"},
    {"name": "Rhaast",     "origins": ["Divinicorp"],     "classes": ["Vanguard"],         "image": "img/Rhaast.jpg"},
    {"name": "Samira",     "origins": ["Street Demon"],    "classes": ["A.M.P."],            "image": "img/Samira.jpg"},
    {"name": "Sejuani",    "origins": ["Exotech"],        "classes": ["Bastion"],           "image": "img/Sejuani.jpg"},
    {"name": "Senna",      "origins": ["Divinicorp"],     "classes": ["Slayer"],            "image": "img/Senna.jpg"},
    {"name": "Seraphine",  "origins": ["Anima Squad"],     "classes": ["Techie"],            "image": "img/Seraphine.jpg"},
    {"name": "Shaco",      "origins": ["Syndicate"],      "classes": ["Slayer"],            "image": "img/Shaco.jpg"},
    {"name": "Shyvana",    "origins": ["Nitro"],          "classes": ["Bastion", "Techie"], "image": "img/Shyvana.jpg"},
    {"name": "Skarner",    "origins": ["BoomBots"],       "classes": ["Vanguard"],          "image": "img/Skarner.jpg"},
    {"name": "Sylas",      "origins": ["Anima Squad"],     "classes": ["Vanguard"],          "image": "img/Sylas.jpg"},
    {"name": "Twisted Fate","origins": ["Syndicate"],     "classes": ["Rapidfire"],         "image": "img/Twisted Fate.jpg"},
    {"name": "Urgot",      "origins": ["BoomBots"],       "classes": ["Executioner"],       "image": "img/Urgot.jpg"},
    {"name": "Varus",      "origins": ["Exotech"],        "classes": ["Executioner"],       "image": "img/Varus.jpg"},
    {"name": "Vayne",      "origins": ["Anima Squad"],     "classes": ["Slayer"],            "image": "img/Vayne.jpg"},
    {"name": "Veigar",     "origins": ["Cyberboss"],      "classes": ["Techie"],            "image": "img/Veigar.jpg"},
    {"name": "Vex",        "origins": ["Divinicorp"],     "classes": ["Executioner"],       "image": "img/Vex.jpg"},
    {"name": "Vi",         "origins": ["Cypher"],         "classes": ["Vanguard"],         "image": "img/Vi.jpg"},
    {"name": "Viego",      "origins": ["Soul Killer", "Golden Ox"], "classes": ["Techie"], "image": "img/Viego.jpg"},
    {"name": "Xayah",      "origins": ["Anima Squad"],     "classes": ["Marksman"],         "image": "img/Xayah.jpg"},
    {"name": "Yuumi",      "origins": ["Anima Squad"],     "classes": ["A.M.P.", "Strategist"], "image": "img/Yuumi.jpg"},
    {"name": "Zac",        "origins": ["Virus"],          "classes": [],                   "image": "img/Zac.jpg"},
    {"name": "Zed",        "origins": ["Cypher"],         "classes": ["Slayer"],           "image": "img/Zed.jpg"},
    {"name": "Zeri",       "origins": ["Exotech"],        "classes": ["Rapidfire"],        "image": "img/Zeri.jpg"},
    {"name": "Ziggs",      "origins": ["Cyberboss"],      "classes": ["Strategist"],       "image": "img/Ziggs.jpg"},
    {"name": "Zyra",       "origins": ["Street Demon"],    "classes": ["Techie"],           "image": "img/Zyra.jpg"}
]
