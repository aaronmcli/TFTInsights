# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests
import time
import json
import os
from datetime import datetime

import tftinsights
import tftinsights.riotapi

# %% [markdown]
# # ETL - EXTRACT
#
# DATA Ingest
# In this notebook, we are polling the API to gather matches data increamentally from a known match id.
# (Can be found in the game client after playing a game).
#
# We then search upward to keep gathering matches. Player ranking / skill data is also immedately gathered.
# It is import to note that the player ranking gathered is at the time of lookup, and not at the time of matched played.
#
# The data is saved raw, in case we decided to change extracted data format.
# If you wish to run this notebook, you'll need to get your own API key and update it in the .env file
#
# No working API key will be uploaded to Github either.

# %%
HEADERS = tftinsights.riotapi.HEADERS

MATCH_URL = "https://americas.api.riotgames.com/tft/match/v1/matches/"
PUUID_TO_SUMMONER_URL = "https://na1.api.riotgames.com/tft/summoner/v1/summoners/by-puuid/"
SUMMONER_TO_RANK_URL = "https://na1.api.riotgames.com/tft/league/v1/entries/by-summoner/"

START_MATCH_ID_NUM = 5297907193
MATCH_REGION_PREFIX = "NA1_"
MAX_CONSECUTIVE_SKIPS = 50000
DATA_DIR = "data"
WAIT_TIME = 0.9
CURRENT_SET_NAME = "TFTSet14"

# %%
os.makedirs(DATA_DIR, exist_ok=True)

#Find the highest number
existing_ids_numeric = []
for filename in os.listdir(DATA_DIR):
    if filename.startswith(tftinsights.riotapi.MATCH_REGION_PREFIX) and filename.endswith(".json"):
        try:
            num = int(filename.removeprefix(MATCH_REGION_PREFIX).removesuffix(".json"))
            existing_ids_numeric.append(num)
        except ValueError:
            continue

max_id = 0
min_id = 0

if existing_ids_numeric:
    min_id = min(existing_ids_numeric)
    max_id = max(existing_ids_numeric)    
    all_scanned_ids = {f"{MATCH_REGION_PREFIX}{i}" for i in range(min_id, max_id + 1)}
else:
    all_scanned_ids = set()

#MATCH_REGION_PREFIX = max_id

def get_match_data(match_id):
    if match_id in all_scanned_ids:
        print(f"⚠️ {match_id} already scanned or skipped.")
        return None

    url = f"{MATCH_URL}{match_id}"
    response = requests.get(url, headers=HEADERS)
    
    for key, value in response.headers.items():
        if 'Rate-Limit' in key:
            print(f'\t{key}: {value}')
        
    time.sleep(WAIT_TIME)  # Avoid hammering the API
    
    if response.status_code == 200:
        data = response.json()
        if data["info"].get("tft_set_core_name") == CURRENT_SET_NAME:
            return data
    elif response.status_code == 429:
        print("Rate limited. Sleeping for 10s...")
        time.sleep(10)
        return get_match_data(match_id)
    elif response.status_code == 404:
        return None
    else:
        print(f"❌ Error {response.status_code} on match {match_id}")
        print(response.text)
    return None


def get_rank_data(puuid):
    status_code, data = tftinsights.riotapi.get_ranked_data_puuid( puuid )
    return status_code,data


def save_match_to_json(match_data, match_id):
    for participant in match_data["info"]["participants"]:
        puuid = participant.get("puuid")
        try:
            code, rank_info = get_rank_data(puuid)            
            rank_info["read_time"] = datetime.now().timestamp()
            if rank_info == None:
                print(f"\t\t⚠️Failed to get rank for {puuid}:\n\t\t{e}")
                rank_info = {}
        except Exception as e:
            print(f"\t\t⚠️Failed to get rank for {puuid}:\n\t\t{e}")
            rank_info = {}
        participant["rank_at_match_time"] = rank_info

    filepath = os.path.join(DATA_DIR, f"{match_id}.json")
    try:
        with open(filepath, "w", encoding='utf-8') as f:
            json.dump(match_data, f, ensure_ascii=False, indent=2)
        print(f"✅Saved {filepath}")
    except Exception as e:
        print(f"❌Failed to save match {match_id}: {e}")


def main():
    current_id = START_MATCH_ID_NUM    
    consecutive_skips = 0

    while consecutive_skips < MAX_CONSECUTIVE_SKIPS:
        match_id = f"{MATCH_REGION_PREFIX}{current_id}"
        print ( "--------------------------------------------")
        print(f"🔍Checking match {match_id}...")

        match_data = get_match_data(match_id)
        if match_data:
            save_match_to_json(match_data, match_id)
            all_scanned_ids.add(match_id)
            consecutive_skips = 0
        else:
            print(f"\t⚠️Skipped {match_id} (Total skips: {consecutive_skips + 1})")
            all_scanned_ids.add(match_id)
            consecutive_skips += 1

        current_id += 1

    print(f"Stopped after {MAX_CONSECUTIVE_SKIPS} consecutive skipped matches.")

# %%
main()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 	⚠️Skipped NA1_5297874079 (Total skips: 17187)
# --------------------------------------------
# 🔍Checking match NA1_5297874080...
# ⚠️ NA1_5297874080 already scanned or skipped.
# 	⚠️Skipped NA1_5297874080 (Total skips: 17188)
# --------------------------------------------
# 🔍Checking match NA1_5297874081...
# ⚠️ NA1_5297874081 already scanned or skipped.
# 	⚠️Skipped NA1_5297874081 (Total skips: 17189)
# --------------------------------------------
# 🔍Checking match NA1_5297874082...
# ⚠️ NA1_5297874082 already scanned or skipped.
# 	⚠️Skipped NA1_5297874082 (Total skips: 17190)
# --------------------------------------------
# 🔍Checking match NA1_5297874083...
# ⚠️ NA1_5297874083 already scanned or skipped.
# 	⚠️Skipped NA1_5297874083 (Total skips: 17191)
# --------------------------------------------
# 🔍Checking match NA1_5297874084...
# ⚠️ NA1_5297874084 already scanned or skipped.
# 	⚠️Skipped NA1_5297874084 (Total skips: 17192)
# --------------------------------------------
# 🔍Checking match NA1_5297874085...
# ⚠️ NA1_5297874085 already scanned or skipped.
# 	⚠️Skipped NA1_5297874085 (Total skips: 17193)
# --------------------------------------------
# 🔍Checking match NA1_5297874086...
# ⚠️ NA1_5297874086 already scanned or skipped.
# 	⚠️Skipped NA1_5297874086 (Total skips: 17194)
# --------------------------------------------
# 🔍Checking match NA1_5297874087...
# ⚠️ NA1_5297874087 already scanned or skipped.
# 	⚠️Skipped NA1_5297874087 (Total skips: 17195)
# --------------------------------------------
# 🔍Checking match NA1_5297874088...
# ⚠️ NA1_5297874088 already scanned or skipped.
# 	⚠️Skipped NA1_5297874088 (Total skips: 17196)
# --------------------------------------------
# 🔍Checking match NA1_5297874089...
# ⚠️ NA1_5297874089 already scanned or skipped.
# 	⚠️Skipped NA1_5297874089 (Total skips: 17197)
# --------------------------------------------
# 🔍Checking match NA1_5297874090...
# ⚠️ NA1_5297874090 already scanned or skipped.
# 	⚠️Skipped NA1_5297874090 (Total skips: 17198)
# --------------------------------------------
# 🔍Checking match NA1_5297874091...
# ⚠️ NA1_5297874091 already scanned or skipped.
# 	⚠️Skipped NA1_5297874091 (Total skips: 17199)
# --------------------------------------------
# 🔍Checking match NA1_5297874092...
# ⚠️ NA1_5297874092 already scanned or skipped.
# 	⚠️Skipped NA1_5297874092 (Total skips: 17200)
# --------------------------------------------
# 🔍Checking match NA1_5297874093...
# ⚠️ NA1_5297874093 already scanned or skipped.
# 	⚠️Skipped NA1_5297874093 (Total skips: 17201)
# --------------------------------------------
# 🔍Checking match NA1_5297874094...
# ⚠️ NA1_5297874094 already scanned or skipped.
# 	⚠️Skipped NA1_5297874094 (Total skips: 17202)
# --------------------------------------------
# 🔍Checking match NA1_5297874095...
# ⚠️ NA1_5297874095 already scanned or skipped.
# 	⚠️Skipped NA1_5297874095 (Total skips: 17203)
# --------------------------------------------
# 🔍Checking match NA1_5297874096...
# ⚠️ NA1_5297874096 already scanned or skipped.
# 	⚠️Skipped NA1_5297874096 (Total skips: 17204)
# --------------------------------------------
# 🔍Checking match NA1_5297874097...
# ⚠️ NA1_5297874097 already scanned or skipped.
# 	⚠️Skipped NA1_5297874097 (Total skips: 17205)
# --------------------------------------------
# 🔍Checking match NA1_5297874098...
# ⚠️ NA1_5297874098 already scanned or skipped.
# 	⚠️Skipped NA1_5297874098 (Total skips: 17206)
# --------------------------------------------
# 🔍Checking match NA1_5297874099...
# ⚠️ NA1_5297874099 already scanned or skipped.
# 	⚠️Skipped NA1_5297874099 (Total skips: 17207)
# --------------------------------------------
# 🔍Checking match NA1_5297874100...
# ⚠️ NA1_5297874100 already scanned or skipped.
# 	⚠️Skipped NA1_5297874100 (Total skips: 17208)
# --------------------------------------------
# 🔍Checking match NA1_5297874101...
# ⚠️ NA1_5297874101 already scanned or skipped.
# 	⚠️Skipped NA1_5297874101 (Total skips: 17209)
# --------------------------------------------
# 🔍Checking match NA1_5297874102...
# ⚠️ NA1_5297874102 already scanned or skipped.
# 	⚠️Skipped NA1_5297874102 (Total skips: 17210)
# --------------------------------------------
# 🔍Checking match NA1_5297874103...
# ⚠️ NA1_5297874103 already scanned or skipped.
# 	⚠️Skipped NA1_5297874103 (Total skips: 17211)
# --------------------------------------------
# 🔍Checking match NA1_5297874104...
# ⚠️ NA1_5297874104 already scanned or skipped.
# 	⚠️Skipped NA1_5297874104 (Total skips: 17212)
# --------------------------------------------
# 🔍Checking match NA1_5297874105...
# ⚠️ NA1_5297874105 already scanned or skipped.
# 	⚠️Skipped NA1_5297874105 (Total skips: 17213)
# --------------------------------------------
# 🔍Checking match NA1_5297874106...
# ⚠️ NA1_5297874106 already scanned or skipped.
# 	⚠️Skipped NA1_5297874106 (Total skips: 17214)
# --------------------------------------------
# 🔍Checking match NA1_5297874107...
# ⚠️ NA1_5297874107 already scanned or skipped.
# 	⚠️Skipped NA1_5297874107 (Total skips: 17215)
# --------------------------------------------
# 🔍Checking match NA1_5297874108...
# ⚠️ NA1_5297874108 already scanned or skipped.
# 	⚠️Skipped NA1_5297874108 (Total skips: 17216)
# --------------------------------------------
# 🔍Checking match NA1_5297874109...
# ⚠️ NA1_5297874109 already scanned or skipped.
# 	⚠️Skipped NA1_5297874109 (Total skips: 17217)
# --------------------------------------------
# 🔍Checking match NA1_5297874110...
# ⚠️ NA1_5297874110 already scanned or skipped.
# 	⚠️Skipped NA1_5297874110 (Total skips: 17218)
# --------------------------------------------
# 🔍Checking match NA1_5297874111...
# ⚠️ NA1_5297874111 already scanned or skipped.
# 	⚠️Skipped NA1_5297874111 (Total skips: 17219)
# --------------------------------------------
# 🔍Checking match NA1_5297874112...
# ⚠️ NA1_5297874112 already scanned or skipped.
# 	⚠️Skipped NA1_5297874112 (Total skips: 17220)
# --------------------------------------------
# 🔍Checking match NA1_5297874113...
# ⚠️ NA1_5297874113 already scanned or skipped.
# 	⚠️Skipped NA1_5297874113 (Total skips: 17221)
# --------------------------------------------
# 🔍Checking match NA1_5297874114...
# ⚠️ NA1_5297874114 already scanned or skipped.
# 	⚠️Skipped NA1_5297874114 (Total skips: 17222)
# --------------------------------------------
# 🔍Checking match NA1_5297874115...
# ⚠️ NA1_5297874115 already scanned or skipped.
# 	⚠️Skipped NA1_5297874115 (Total skips: 17223)
# --------------------------------------------
# 🔍Checking match NA1_5297874116...
# ⚠️ NA1_5297874116 already scanned or skipped.
# 	⚠️Skipped NA1_5297874116 (Total skips: 17224)
# --------------------------------------------
# 🔍Checking match NA1_5297874117...
# ⚠️ NA1_5297874117 already scanned or skipped.
# 	⚠️Skipped NA1_5297874117 (Total skips: 17225)
# --------------------------------------------
# 🔍Checking match NA1_5297874118...
# ⚠️ NA1_5297874118 already scanned or skipped.
# 	⚠️Skipped NA1_5297874118 (Total skips: 17226)
# --------------------------------------------
# 🔍Checking match NA1_5297874119...
# ⚠️ NA1_5297874119 already scanned or skipped.
# 	⚠️Skipped NA1_5297874119 (Total skips: 17227)
# --------------------------------------------
# 🔍Checking match NA1_5297874120...
# ⚠️ NA1_5297874120 already scanned or skipped.
# 	⚠️Skipped NA1_5297874120 (Total skips: 17228)
# --------------------------------------------
# 🔍Checking match NA1_5297874121...
# ⚠️ NA1_5297874121 already scanned or skipped.
# 	⚠️Skipped NA1_5297874121 (Total skips: 17229)
# --------------------------------------------
# 🔍Checking match NA1_5297874122...
# ⚠️ NA1_5297874122 already scanned or skipped.
# 	⚠️Skipped NA1_5297874122 (Total skips: 17230)
# --------------------------------------------
# 🔍Checking match NA1_5297874123...
# ⚠️ NA1_5297874123 already scanned or skipped.
# 	⚠️Skipped NA1_5297874123 (Total skips: 17231)
# --------------------------------------------
# 🔍Checking match NA1_5297874124...
# ⚠️ NA1_5297874124 already scanned or skipped.
# 	⚠️Skipped NA1_5297874124 (Total skips: 17232)
# --------------------------------------------
# 🔍Checking match NA1_5297874125...
# ⚠️ NA1_5297874125 already scanned or skipped.
# 	⚠️Skipped NA1_5297874125 (Total skips: 17233)
# --------------------------------------------
# 🔍Checking match NA1_5297874126...
# ⚠️ NA1_5297874126 already scanned or skipped.
# 	⚠️Skipped NA1_5297874126 (Total skips: 17234)
# --------------------------------------------
# 🔍Checking match NA1_5297874127...
# ⚠️ NA1_5297874127 already scanned or skipped.
# 	⚠️Skipped NA1_5297874127 (Total skips: 17235)
# --------------------------------------------
# 🔍Checking match NA1_5297874128...
# ⚠️ NA1_5297874128 already scanned or skipped.
# 	⚠️Skipped NA1_5297874128 (Total skips: 17236)
# --------------------------------------------
# 🔍Checking match NA1_5297874129...
# ⚠️ NA1_5297874129 already scanned or skipped.
# 	⚠️Skipped NA1_5297874129 (Total skips: 17237)
# --------------------------------------------
# 🔍Checking match NA1_5297874130...
# ⚠️ NA1_5297874130 already scanned or skipped.
# 	⚠️Skipped NA1_5297874130 (Total skips: 17238)
# --------------------------------------------
# 🔍Checking match NA1_5297874131...
# ⚠️ NA1_5297874131 already scanned or skipped.
# 	⚠️Skipped NA1_5297874131 (Total skips: 17239)
# --------------------------------------------
# 🔍Checking match NA1_5297874132...
# ⚠️ NA1_5297874132 already scanned or skipped.
# 	⚠️Skipped NA1_5297874132 (Total skips: 17240)
# --------------------------------------------
# 🔍Checking match NA1_5297874133...
# ⚠️ NA1_5297874133 already scanned or skipped.
# 	⚠️Skipped NA1_5297874133 (Total skips: 17241)
# --------------------------------------------
# 🔍Checking match NA1_5297874134...
# ⚠️ NA1_5297874134 already scanned or skipped.
# 	⚠️Skipped NA1_5297874134 (Total skips: 17242)
# --------------------------------------------
# 🔍Checking match NA1_5297874135...
# ⚠️ NA1_5297874135 already scanned or skipped.
# 	⚠️Skipped NA1_5297874135 (Total skips: 17243)
# --------------------------------------------
# 🔍Checking match NA1_5297874136...
# ⚠️ NA1_5297874136 already scanned or skipped.
# 	⚠️Skipped NA1_5297874136 (Total skips: 17244)
# --------------------------------------------
# 🔍Checking match NA1_5297874137...
# ⚠️ NA1_5297874137 already scanned or skipped.
# 	⚠️Skipped NA1_5297874137 (Total skips: 17245)
# --------------------------------------------
# 🔍Checking match NA1_5297874138...
# ⚠️ NA1_5297874138 already scanned or skipped.
# 	⚠️Skipped NA1_5297874138 (Total skips: 17246)
# --------------------------------------------
# 🔍Checking match NA1_5297874139...
# ⚠️ NA1_5297874139 already scanned or skipped.
# 	⚠️Skipped NA1_5297874139 (Total skips: 17247)
# --------------------------------------------
# 🔍Checking match NA1_5297874140...
# ⚠️ NA1_5297874140 already scanned or skipped.
# 	⚠️Skipped NA1_5297874140 (Total skips: 17248)
# --------------------------------------------
# 🔍Checking match NA1_5297874141...
# ⚠️ NA1_5297874141 already scanned or skipped.
# 	⚠️Skipped NA1_5297874141 (Total skips: 17249)
# --------------------------------------------
# 🔍Checking match NA1_5297874142...
# ⚠️ NA1_5297874142 already scanned or skipped.
# 	⚠️Skipped NA1_5297874142 (Total skips: 17250)
# --------------------------------------------
# 🔍Checking match NA1_5297874143...
# ⚠️ NA1_5297874143 already scanned or skipped.
# 	⚠️Skipped NA1_5297874143 (Total skips: 17251)
# --------------------------------------------
# 🔍Checking match NA1_5297874144...
# ⚠️ NA1_5297874144 already scanned or skipped.
# 	⚠️Skipped NA1_5297874144 (Total skips: 17252)
# --------------------------------------------
# 🔍Checking match NA1_5297874145...
# ⚠️ NA1_5297874145 already scanned or skipped.
# 	⚠️Skipped NA1_5297874145 (Total skips: 17253)
# --------------------------------------------
# 🔍Checking match NA1_5297874146...
# ⚠️ NA1_5297874146 already scanned or skipped.
# 	⚠️Skipped NA1_5297874146 (Total skips: 17254)
# --------------------------------------------
# 🔍Checking match NA1_5297874147...
# ⚠️ NA1_5297874147 already scanned or skipped.
# 	⚠️Skipped NA1_5297874147 (Total skips: 17255)
# --------------------------------------------
# 🔍Checking match NA1_5297874148...
# ⚠️ NA1_5297874148 already scanned or skipped.
# 	⚠️Skipped NA1_5297874148 (Total skips: 17256)
# --------------------------------------------
# 🔍Checking match NA1_5297874149...
# ⚠️ NA1_5297874149 already scanned or skipped.
# 	⚠️Skipped NA1_5297874149 (Total skips: 17257)
# --------------------------------------------
# 🔍Checking match NA1_5297874150...
# ⚠️ NA1_5297874150 already scanned or skipped.
# 	⚠️Skipped NA1_5297874150 (Total skips: 17258)
# --------------------------------------------
# 🔍Checking match NA1_5297874151...
# ⚠️ NA1_5297874151 already scanned or skipped.
# 	⚠️Skipped NA1_5297874151 (Total skips: 17259)
# --------------------------------------------
# 🔍Checking match NA1_5297874152...
# ⚠️ NA1_5297874152 already scanned or skipped.
# 	⚠️Skipped NA1_5297874152 (Total skips: 17260)
# --------------------------------------------
# 🔍Checking match NA1_5297874153...
# ⚠️ NA1_5297874153 already scanned or skipped.
# 	⚠️Skipped NA1_5297874153 (Total skips: 17261)
# --------------------------------------------
# 🔍Checking match NA1_5297874154...
# ⚠️ NA1_5297874154 already scanned or skipped.
# 	⚠️Skipped NA1_5297874154 (Total skips: 17262)
# --------------------------------------------
# 🔍Checking match NA1_5297874155...
# ⚠️ NA1_5297874155 already scanned or skipped.
# 	⚠️Skipped NA1_5297874155 (Total skips: 17263)
# --------------------------------------------
# 🔍Checking match NA1_5297874156...
# ⚠️ NA1_5297874156 already scanned or skipped.
# 	⚠️Skipped NA1_5297874156 (Total skips: 17264)
# --------------------------------------------
# 🔍Checking match NA1_5297874157...
# ⚠️ NA1_5297874157 already scanned or skipped.
# 	⚠️Skipped NA1_5297874157 (Total skips: 17265)
# --------------------------------------------
# 🔍Checking match NA1_5297874158...
# ⚠️ NA1_5297874158 already scanned or skipped.
# 	⚠️Skipped NA1_5297874158 (Total skips: 17266)
# --------------------------------------------
# 🔍Checking match NA1_5297874159...
# ⚠️ NA1_5297874159 already scanned or skipped.
# 	⚠️Skipped NA1_5297874159 (Total skips: 17267)
# --------------------------------------------
# 🔍Checking match NA1_5297874160...
# ⚠️ NA1_5297874160 already scanned or skipped.
# 	⚠️Skipped NA1_5297874160 (Total skips: 17268)
# --------------------------------------------
# 🔍Checking match NA1_5297874161...
# ⚠️ NA1_5297874161 already scanned or skipped.
# 	⚠️Skipped NA1_5297874161 (Total skips: 17269)
# --------------------------------------------
# 🔍Checking match NA1_5297874162...
# ⚠️ NA1_5297874162 already scanned or skipped.
# 	⚠️Skipped NA1_5297874162 (Total skips: 17270)
# --------------------------------------------
# 🔍Checking match NA1_5297874163...
# ⚠️ NA1_5297874163 already scanned or skipped.
# 	⚠️Skipped NA1_5297874163 (Total skips: 17271)
# --------------------------------------------
# 🔍Checking match NA1_5297874164...
# ⚠️ NA1_5297874164 already scanned or skipped.
# 	⚠️Skipped NA1_5297874164 (Total skips: 17272)
# --------------------------------------------
# 🔍Checking match NA1_5297874165...
# ⚠️ NA1_5297874165 already scanned or skipped.
# 	⚠️Skipped NA1_5297874165 (Total skips: 17273)
# --------------------------------------------
# 🔍Checking match NA1_5297874166...
# ⚠️ NA1_5297874166 already scanned or skipped.
# 	⚠️Skipped NA1_5297874166 (Total skips: 17274)
# --------------------------------------------
# 🔍Checking match NA1_5297874167...
# ⚠️ NA1_5297874167 already scanned or skipped.
# 	⚠️Skipped NA1_5297874167 (Total skips: 17275)
# --------------------------------------------
# 🔍Checking match NA1_5297874168...
# ⚠️ NA1_5297874168 already scanned or skipped.
# 	⚠️Skipped NA1_5297874168 (Total skips: 17276)
# --------------------------------------------
# 🔍Checking match NA1_5297874169...
# ⚠️ NA1_5297874169 already scanned or skipped.
# 	⚠️Skipped NA1_5297874169 (Total skips: 17277)
# --------------------------------------------
# 🔍Checking match NA1_5297874170...
# ⚠️ NA1_5297874170 already scanned or skipped.
# 	⚠️Skipped NA1_5297874170 (Total skips: 17278)
# --------------------------------------------
# 🔍Checking match NA1_5297874171...
# ⚠️ NA1_5297874171 already scanned or skipped.
# 	⚠️Skipped NA1_5297874171 (Total skips: 17279)
# --------------------------------------------
# 🔍Checking match NA1_5297874172...
# ⚠️ NA1_5297874172 already scanned or skipped.
# 	⚠️Skipped NA1_5297874172 (Total skips: 17280)
# --------------------------------------------
# 🔍Checking match NA1_5297874173...
# ⚠️ NA1_5297874173 already scanned or skipped.
# 	⚠️Skipped NA1_5297874173 (Total skips: 17281)
# --------------------------------------------
# 🔍Checking match NA1_5297874174...
# ⚠️ NA1_5297874174 already scanned or skipped.
# 	⚠️Skipped NA1_5297874174 (Total skips: 17282)
# --------------------------------------------
# 🔍Checking match NA1_5297874175...
# ⚠️ NA1_5297874175 already scanned or skipped.
# 	⚠️Skipped NA1_5297874175 (Total skips: 17283)
# --------------------------------------------
# 🔍Checking match NA1_5297874176...
# ⚠️ NA1_5297874176 already scanned or skipped.
# 	⚠️Skipped NA1_5297874176 (Total skips: 17284)
# --------------------------------------------
# 🔍Checking match NA1_5297874177...
# ⚠️ NA1_5297874177 already scanned or skipped.
# 	⚠️Skipped NA1_5297874177 (Total skips: 17285)
# --------------------------------------------
# 🔍Checking match NA1_5297874178...
# ⚠️ NA1_5297874178 already scanned or skipped.
# 	⚠️Skipped NA1_5297874178 (Total skips: 17286)
# --------------------------------------------
# 🔍Checking match NA1_5297874179...
# ⚠️ NA1_5297874179 already scanned or skipped.
# 	⚠️Skipped NA1_5297874179 (Total skips: 17287)
# --------------------------------------------
# 🔍Checking match NA1_5297874180...
# ⚠️ NA1_5297874180 already scanned or skipped.
# 	⚠️Skipped NA1_5297874180 (Total skips: 17288)
# --------------------------------------------
# 🔍Checking match NA1_5297874181...
# ⚠️ NA1_5297874181 already scanned or skipped.
# 	⚠️Skipped NA1_5297874181 (Total skips: 17289)
# --------------------------------------------
# 🔍Checking match NA1_5297874182...
# ⚠️ NA1_5297874182 already scanned or skipped.
# 	⚠️Skipped NA1_5297874182 (Total skips: 17290)
# --------------------------------------------
# 🔍Checking match NA1_5297874183...
# ⚠️ NA1_5297874183 already scanned or skipped.
# 	⚠️Skipped NA1_5297874183 (Total skips: 17291)
# --------------------------------------------
# 🔍Checking match NA1_5297874184...
# ⚠️ NA1_5297874184 already scanned or skipped.
# 	⚠️Skipped NA1_5297874184 (Total skips: 17292)
# --------------------------------------------
# 🔍Checking match NA1_5297874185...
# ⚠️ NA1_5297874185 already scanned or skipped.
# 	⚠️Skipped NA1_5297874185 (Total skips: 17293)
# --------------------------------------------
# 🔍Checking match NA1_5297874186...
# ⚠️ NA1_5297874186 already scanned or skipped.
# 	⚠️Skipped NA1_5297874186 (Total skips: 17294)
# --------------------------------------------
# 🔍Checking match NA1_5297874187...
# ⚠️ NA1_5297874187 already scanned or skipped.
# 	⚠️Skipped NA1_5297874187 (Total skips: 17295)
# --------------------------------------------
# 🔍Checking match NA1_5297874188...
# ⚠️ NA1_5297874188 already scanned or skipped.
# 	⚠️Skipped NA1_5297874188 (Total skips: 17296)
# --------------------------------------------
# 🔍Checking match NA1_5297874189...
# ⚠️ NA1_5297874189 already scanned or skipped.
# 	⚠️Skipped NA1_5297874189 (Total skips: 17297)
# --------------------------------------------
# 🔍Checking match NA1_5297874190...
# ⚠️ NA1_5297874190 already scanned or skipped.
# 	⚠️Skipped NA1_5297874190 (Total skips: 17298)
# --------------------------------------------
# 🔍Checking match NA1_5297874191...
# ⚠️ NA1_5297874191 already scanned or skipped.
# 	⚠️Skipped NA1_5297874191 (Total skips: 17299)
# --------------------------------------------
# 🔍Checking match NA1_5297874192...
# ⚠️ NA1_5297874192 already scanned or skipped.
# 	⚠️Skipped NA1_5297874192 (Total skips: 17300)
# --------------------------------------------
# 🔍Checking match NA1_5297874193...
# ⚠️ NA1_5297874193 already scanned or skipped.
# 	⚠️Skipped NA1_5297874193 (Total skips: 17301)
# --------------------------------------------
# 🔍Checking match NA1_5297874194...
# ⚠️ NA1_5297874194 already scanned or skipped.
# 	⚠️Skipped NA1_5297874194 (Total skips: 17302)
# --------------------------------------------
# 🔍Checking match NA1_5297874195...
# ⚠️ NA1_5297874195 already scanned or skipped.
# 	⚠️Skipped NA1_5297874195 (Total skips: 17303)
# --------------------------------------------
# 🔍Checking match NA1_5297874196...
# ⚠️ NA1_5297874196 already scanned or skipped.
# 	⚠️Skipped NA1_5297874196 (Total skips: 17304)
# --------------------------------------------
# 🔍Checking match NA1_5297874197...
# ⚠️ NA1_5297874197 already scanned or skipped.
# 	⚠️Skipped NA1_5297874197 (Total skips: 17305)
# --------------------------------------------
# 🔍Checking match NA1_5297874198...
# ⚠️ NA1_5297874198 already scanned or skipped.
# 	⚠️Skipped NA1_5297874198 (Total skips: 17306)
# --------------------------------------------
# 🔍Checking match NA1_5297874199...
# ⚠️ NA1_5297874199 already scanned or skipped.
# 	⚠️Skipped NA1_5297874199 (Total skips: 17307)
# --------------------------------------------
# 🔍Checking match NA1_5297874200...
# ⚠️ NA1_5297874200 already scanned or skipped.
# 	⚠️Skipped NA1_5297874200 (Total skips: 17308)
# --------------------------------------------
# 🔍Checking match NA1_5297874201...
# ⚠️ NA1_5297874201 already scanned or skipped.
# 	⚠️Skipped NA1_5297874201 (Total skips: 17309)
# --------------------------------------------
# 🔍Checking match NA1_5297874202...
# ⚠️ NA1_5297874202 already scanned or skipped.
# 	⚠️Skipped NA1_5297874202 (Total skips: 17310)
# --------------------------------------------
# 🔍Checking match NA1_5297874203...
# ⚠️ NA1_5297874203 already scanned or skipped.
# 	⚠️Skipped NA1_5297874203 (Total skips: 17311)
# --------------------------------------------
# 🔍Checking match NA1_5297874204...
# ⚠️ NA1_5297874204 already scanned or skipped.
# 	⚠️Skipped NA1_5297874204 (Total skips: 17312)
# --------------------------------------------
# 🔍Checking match NA1_5297874205...
# ⚠️ NA1_5297874205 already scanned or skipped.
# 	⚠️Skipped NA1_5297874205 (Total skips: 17313)
# --------------------------------------------
# 🔍Checking match NA1_5297874206...
# ⚠️ NA1_5297874206 already scanned or skipped.
# 	⚠️Skipped NA1_5297874206 (Total skips: 17314)
# --------------------------------------------
# 🔍Checking match NA1_5297874207...
# ⚠️ NA1_5297874207 already scanned or skipped.
# 	⚠️Skipped NA1_5297874207 (Total skips: 17315)
# --------------------------------------------
# 🔍Checking match NA1_5297874208...
# ⚠️ NA1_5297874208 already scanned or skipped.
# 	⚠️Skipped NA1_5297874208 (Total skips: 17316)
# --------------------------------------------
# 🔍Checking match NA1_5297874209...
# ⚠️ NA1_5297874209 already scanned or skipped.
# 	⚠️Skipped NA1_5297874209 (Total skips: 17317)
# --------------------------------------------
# 🔍Checking match NA1_5297874210...
# ⚠️ NA1_5297874210 already scanned or skipped.
# 	⚠️Skipped NA1_5297874210 (Total skips: 17318)
# --------------------------------------------
# 🔍Checking match NA1_5297874211...
# ⚠️ NA1_5297874211 already scanned or skipped.
# 	⚠️Skipped NA1_5297874211 (Total skips: 17319)
# --------------------------------------------
# 🔍Checking match NA1_5297874212...
# ⚠️ NA1_5297874212 already scanned or skipped.
# 	⚠️Skipped NA1_5297874212 (Total skips: 17320)
# --------------------------------------------
# 🔍Checking match NA1_5297874213...
# ⚠️ NA1_5297874213 already scanned or skipped.
# 	⚠️Skipped NA1_5297874213 (Total skips: 17321)
# --------------------------------------------
# 🔍Checking match NA1_5297874214...
# ⚠️ NA1_5297874214 already scanned or skipped.
# 	⚠️Skipped NA1_5297874214 (Total skips: 17322)
# --------------------------------------------
# 🔍Checking match NA1_5297874215...
# ⚠️ NA1_5297874215 already scanned or skipped.
# 	⚠️Skipped NA1_5297874215 (Total skips: 17323)
# --------------------------------------------
# 🔍Checking match NA1_5297874216...
# ⚠️ NA1_5297874216 already scanned or skipped.
# 	⚠️Skipped NA1_5297874216 (Total skips: 17324)
# --------------------------------------------
# 🔍Checking match NA1_5297874217...
# ⚠️ NA1_5297874217 already scanned or skipped.
# 	⚠️Skipped NA1_5297874217 (Total skips: 17325)
# --------------------------------------------
# 🔍Checking match NA1_5297874218...
# ⚠️ NA1_5297874218 already scanned or skipped.
# 	⚠️Skipped NA1_5297874218 (Total skips: 17326)
# --------------------------------------------
# 🔍Checking match NA1_5297874219...
# ⚠️ NA1_5297874219 already scanned or skipped.
# 	⚠️Skipped NA1_5297874219 (Total skips: 17327)
# --------------------------------------------
# 🔍Checking match NA1_5297874220...
# ⚠️ NA1_5297874220 already scanned or skipped.
# 	⚠️Skipped NA1_5297874220 (Total skips: 17328)
# --------------------------------------------
# 🔍Checking match NA1_5297874221...
# ⚠️ NA1_5297874221 already scanned or skipped.
# 	⚠️Skipped NA1_5297874221 (Total skips: 17329)
# --------------------------------------------
# 🔍Checking match NA1_5297874222...
# ⚠️ NA1_5297874222 already scanned or skipped.
# 	⚠️Skipped NA1_5297874222 (Total skips: 17330)
# --------------------------------------------
# 🔍Checking match NA1_5297874223...
# ⚠️ NA1_5297874223 already scanned or skipped.
# 	⚠️Skipped NA1_5297874223 (Total skips: 17331)
# --------------------------------------------
# 🔍Checking match NA1_5297874224...
# ⚠️ NA1_5297874224 already scanned or skipped.
# 	⚠️Skipped NA1_5297874224 (Total skips: 17332)
# --------------------------------------------
# 🔍Checking match NA1_5297874225...
# ⚠️ NA1_5297874225 already scanned or skipped.
# 	⚠️Skipped NA1_5297874225 (Total skips: 17333)
# --------------------------------------------
# 🔍Checking match NA1_5297874226...
# ⚠️ NA1_5297874226 already scanned or skipped.
# 	⚠️Skipped NA1_5297874226 (Total skips: 17334)
# --------------------------------------------
# 🔍Checking match NA1_5297874227...
# ⚠️ NA1_5297874227 already scanned or skipped.
# 	⚠️Skipped NA1_5297874227 (Total skips: 17335)
# --------------------------------------------
# 🔍Checking match NA1_5297874228...
# ⚠️ NA1_5297874228 already scanned or skipped.
# 	⚠️Skipped NA1_5297874228 (Total skips: 17336)
# --------------------------------------------
# 🔍Checking match NA1_5297874229...
# ⚠️ NA1_5297874229 already scanned or skipped.
# 	⚠️Skipped NA1_5297874229 (Total skips: 17337)
# --------------------------------------------
# 🔍Checking match NA1_5297874230...
# ⚠️ NA1_5297874230 already scanned or skipped.
# 	⚠️Skipped NA1_5297874230 (Total skips: 17338)
# --------------------------------------------
# 🔍Checking match NA1_5297874231...
# ⚠️ NA1_5297874231 already scanned or skipped.
# 	⚠️Skipped NA1_5297874231 (Total skips: 17339)
# --------------------------------------------
# 🔍Checking match NA1_5297874232...
# ⚠️ NA1_5297874232 already scanned or skipped.
# 	⚠️Skipped NA1_5297874232 (Total skips: 17340)
# --------------------------------------------
# 🔍Checking match NA1_5297874233...
# ⚠️ NA1_5297874233 already scanned or skipped.
# 	⚠️Skipped NA1_5297874233 (Total skips: 17341)
# --------------------------------------------
# 🔍Checking match NA1_5297874234...
# ⚠️ NA1_5297874234 already scanned or skipped.
# 	⚠️Skipped NA1_5297874234 (Total skips: 17342)
# --------------------------------------------
# 🔍Checking match NA1_5297874235...
# ⚠️ NA1_5297874235 already scanned or skipped.
# 	⚠️Skipped NA1_5297874235 (Total skips: 17343)
# --------------------------------------------
# 🔍Checking match NA1_5297874236...
# ⚠️ NA1_5297874236 already scanned or skipped.
# 	⚠️Skipped NA1_5297874236 (Total skips: 17344)
# --------------------------------------------
# 🔍Checking match NA1_5297874237...
# ⚠️ NA1_5297874237 already scanned or skipped.
# 	⚠️Skipped NA1_5297874237 (Total skips: 17345)
# --------------------------------------------
# 🔍Checking match NA1_5297874238...
# ⚠️ NA1_5297874238 already scanned or skipped.
# 	⚠️Skipped NA1_5297874238 (Total skips: 17346)
# --------------------------------------------
# 🔍Checking match NA1_5297874239...
# ⚠️ NA1_5297874239 already scanned or skipped.
# 	⚠️Skipped NA1_5297874239 (Total skips: 17347)
# --------------------------------------------
# 🔍Checking match NA1_5297874240...
# ⚠️ NA1_5297874240 already scanned or skipped.
# 	⚠️Skipped NA1_5297874240 (Total skips: 17348)
# --------------------------------------------
# 🔍Checking match NA1_5297874241...
# ⚠️ NA1_5297874241 already scanned or skipped.
# 	⚠️Skipped NA1_5297874241 (Total skips: 17349)
# --------------------------------------------
# 🔍Checking match NA1_5297874242...
# ⚠️ NA1_5297874242 already scanned or skipped.
# 	⚠️Skipped NA1_5297874242 (Total skips: 17350)
# --------------------------------------------
# 🔍Checking match NA1_5297874243...
# ⚠️ NA1_5297874243 already scanned or skipped.
# 	⚠️Skipped NA1_5297874243 (Total skips: 17351)
# --------------------------------------------
# 🔍Checking match NA1_5297874244...
# ⚠️ NA1_5297874244 already scanned or skipped.
# 	⚠️Skipped NA1_5297874244 (Total skips: 17352)
# --------------------------------------------
# 🔍Checking match NA1_5297874245...
# ⚠️ NA1_5297874245 already scanned or skipped.
# 	⚠️Skipped NA1_5297874245 (Total skips: 17353)
# --------------------------------------------
# 🔍Checking match NA1_5297874246...
# ⚠️ NA1_5297874246 already scanned or skipped.
# 	⚠️Skipped NA1_5297874246 (Total skips: 17354)
# --------------------------------------------
# 🔍Checking match NA1_5297874247...
# ⚠️ NA1_5297874247 already scanned or skipped.
# 	⚠️Skipped NA1_5297874247 (Total skips: 17355)
# --------------------------------------------
# 🔍Checking match NA1_5297874248...
# ⚠️ NA1_5297874248 already scanned or skipped.
# 	⚠️Skipped NA1_5297874248 (Total skips: 17356)
# --------------------------------------------
# 🔍Checking match NA1_5297874249...
# ⚠️ NA1_5297874249 already scanned or skipped.
# 	⚠️Skipped NA1_5297874249 (Total skips: 17357)
# --------------------------------------------
# 🔍Checking match NA1_5297874250...
# ⚠️ NA1_5297874250 already scanned or skipped.
# 	⚠️Skipped NA1_5297874250 (Total skips: 17358)
# --------------------------------------------
# 🔍Checking match NA1_5297874251...
# ⚠️ NA1_5297874251 already scanned or skipped.
# 	⚠️Skipped NA1_5297874251 (Total skips: 17359)
# --------------------------------------------
# 🔍Checking match NA1_5297874252...
# ⚠️ NA1_5297874252 already scanned or skipped.
# 	⚠️Skipped NA1_5297874252 (Total skips: 17360)
# --------------------------------------------
# 🔍Checking match NA1_5297874253...
# ⚠️ NA1_5297874253 already scanned or skipped.
# 	⚠️Skipped NA1_5297874253 (Total skips: 17361)
# --------------------------------------------
# 🔍Checking match NA1_5297874254...
# ⚠️ NA1_5297874254 already scanned or skipped.
# 	⚠️Skipped NA1_5297874254 (Total skips: 17362)
# --------------------------------------------
# 🔍Checking match NA1_5297874255...
# ⚠️ NA1_5297874255 already scanned or skipped.
# 	⚠️Skipped NA1_5297874255 (Total skips: 17363)
# --------------------------------------------
# 🔍Checking match NA1_5297874256...
# ⚠️ NA1_5297874256 already scanned or skipped.
# 	⚠️Skipped NA1_5297874256 (Total skips: 17364)
# --------------------------------------------
# 🔍Checking match NA1_5297874257...
# ⚠️ NA1_5297874257 already scanned or skipped.
# 	⚠️Skipped NA1_5297874257 (Total skips: 17365)
# --------------------------------------------
# 🔍Checking match NA1_5297874258...
# ⚠️ NA1_5297874258 already scanned or skipped.
# 	⚠️Skipped NA1_5297874258 (Total skips: 17366)
# --------------------------------------------
# 🔍Checking match NA1_5297874259...
# ⚠️ NA1_5297874259 already scanned or skipped.
# 	⚠️Skipped NA1_5297874259 (Total skips: 17367)
# --------------------------------------------
# 🔍Checking match NA1_5297874260...
# ⚠️ NA1_5297874260 already scanned or skipped.
# 	⚠️Skipped NA1_5297874260 (Total skips: 17368)
# --------------------------------------------
# 🔍Checking match NA1_5297874261...
# ⚠️ NA1_5297874261 already scanned or skipped.
# 	⚠️Skipped NA1_5297874261 (Total skips: 17369)
# --------------------------------------------
# 🔍Checking match NA1_5297874262...
# ⚠️ NA1_5297874262 already scanned or skipped.
# 	⚠️Skipped NA1_5297874262 (Total skips: 17370)
# --------------------------------------------
# 🔍Checking match NA1_5297874263...
# ⚠️ NA1_5297874263 already scanned or skipped.
# 	⚠️Skipped NA1_5297874263 (Total skips: 17371)
# --------------------------------------------
# 🔍Checking match NA1_5297874264...
# ⚠️ NA1_5297874264 already scanned or skipped.
# 	⚠️Skipped NA1_5297874264 (Total skips: 17372)
# --------------------------------------------
# 🔍Checking match NA1_5297874265...
# ⚠️ NA1_5297874265 already scanned or skipped.
# 	⚠️Skipped NA1_5297874265 (Total skips: 17373)
# --------------------------------------------
# 🔍Checking match NA1_5297874266...
# ⚠️ NA1_5297874266 already scanned or skipped.
# 	⚠️Skipped NA1_5297874266 (Total skips: 17374)
# --------------------------------------------
# 🔍Checking match NA1_5297874267...
# ⚠️ NA1_5297874267 already scanned or skipped.
# 	⚠️Skipped NA1_5297874267 (Total skips: 17375)
# --------------------------------------------
# 🔍Checking match NA1_5297874268...
# ⚠️ NA1_5297874268 already scanned or skipped.
# 	⚠️Skipped NA1_5297874268 (Total skips: 17376)
# --------------------------------------------
# 🔍Checking match NA1_5297874269...
# ⚠️ NA1_5297874269 already scanned or skipped.
# 	⚠️Skipped NA1_5297874269 (Total skips: 17377)
# --------------------------------------------
# 🔍Checking match NA1_5297874270...
# ⚠️ NA1_5297874270 already scanned or skipped.
# 	⚠️Skipped NA1_5297874270 (Total skips: 17378)
# --------------------------------------------
# 🔍Checking match NA1_5297874271...
# ⚠️ NA1_5297874271 already scanned or skipped.
# 	⚠️Skipped NA1_5297874271 (Total skips: 17379)
# --------------------------------------------
# 🔍Checking match NA1_5297874272...
# ⚠️ NA1_5297874272 already scanned or skipped.
# 	⚠️Skipped NA1_5297874272 (Total skips: 17380)
# --------------------------------------------
# 🔍Checking match NA1_5297874273...
# ⚠️ NA1_5297874273 already scanned or skipped.
# 	⚠️Skipped NA1_5297874273 (Total skips: 17381)
# --------------------------------------------
# 🔍Checking match NA1_5297874274...
# ⚠️ NA1_5297874274 already scanned or skipped.
# 	⚠️Skipped NA1_5297874274 (Total skips: 17382)
# --------------------------------------------
# 🔍Checking match NA1_5297874275...
# ⚠️ NA1_5297874275 already scanned or skipped.
# 	⚠️Skipped NA1_5297874275 (Total skips: 17383)
# --------------------------------------------
# 🔍Checking match NA1_5297874276...
# ⚠️ NA1_5297874276 already scanned or skipped.
# 	⚠️Skipped NA1_5297874276 (Total skips: 17384)
# --------------------------------------------
# 🔍Checking match NA1_5297874277...
# ⚠️ NA1_5297874277 already scanned or skipped.
# 	⚠️Skipped NA1_5297874277 (Total skips: 17385)
# --------------------------------------------
# 🔍Checking match NA1_5297874278...
# ⚠️ NA1_5297874278 already scanned or skipped.
# 	⚠️Skipped NA1_5297874278 (Total skips: 17386)
# --------------------------------------------
# 🔍Checking match NA1_5297874279...
# ⚠️ NA1_5297874279 already scanned or skipped.
# 	⚠️Skipped NA1_5297874279 (Total skips: 17387)
# --------------------------------------------
# 🔍Checking match NA1_5297874280...
# ⚠️ NA1_5297874280 already scanned or skipped.
# 	⚠️Skipped NA1_5297874280 (Total skips: 17388)
# --------------------------------------------
# 🔍Checking match NA1_5297874281...
# ⚠️ NA1_5297874281 already scanned or skipped.
# 	⚠️Skipped NA1_5297874281 (Total skips: 17389)
# --------------------------------------------
# 🔍Checking match NA1_5297874282...
# ⚠️ NA1_5297874282 already scanned or skipped.
# 	⚠️Skipped NA1_5297874282 (Total skips: 17390)
# --------------------------------------------
# 🔍Checking match NA1_5297874283...
# ⚠️ NA1_5297874283 already scanned or skipped.
# 	⚠️Skipped NA1_5297874283 (Total skips: 17391)
# --------------------------------------------
# 🔍Checking match NA1_5297874284...
# ⚠️ NA1_5297874284 already scanned or skipped.
# 	⚠️Skipped NA1_5297874284 (Total skips: 17392)
# --------------------------------------------
# 🔍Checking match NA1_5297874285...
# ⚠️ NA1_5297874285 already scanned or skipped.
# 	⚠️Skipped NA1_5297874285 (Total skips: 17393)
# --------------------------------------------
# 🔍Checking match NA1_5297874286...
# ⚠️ NA1_5297874286 already scanned or skipped.
# 	⚠️Skipped NA1_5297874286 (Total skips: 17394)
# --------------------------------------------
# 🔍Checking match NA1_5297874287...
# ⚠️ NA1_5297874287 already scanned or skipped.
# 	⚠️Skipped NA1_5297874287 (Total skips: 17395)
# --------------------------------------------
# 🔍Checking match NA1_5297874288...
# ⚠️ NA1_5297874288 already scanned or skipped.
# 	⚠️Skipped NA1_5297874288 (Total skips: 17396)
# --------------------------------------------
# 🔍Checking match NA1_5297874289...
# ⚠️ NA1_5297874289 already scanned or skipped.
# 	⚠️Skipped NA1_5297874289 (Total skips: 17397)
# --------------------------------------------
# 🔍Checking match NA1_5297874290...
# ⚠️ NA1_5297874290 already scanned or skipped.
# 	⚠️Skipped NA1_5297874290 (Total skips: 17398)
# --------------------------------------------
# 🔍Checking match NA1_5297874291...
# ⚠️ NA1_5297874291 already scanned or skipped.
# 	⚠️Skipped NA1_5297874291 (Total skips: 17399)
# --------------------------------------------
# 🔍Checking match NA1_5297874292...
# ⚠️ NA1_5297874292 already scanned or skipped.
# 	⚠️Skipped NA1_5297874292 (Total skips: 17400)
# --------------------------------------------
# 🔍Checking match NA1_5297874293...
# ⚠️ NA1_5297874293 already scanned or skipped.
# 	⚠️Skipped NA1_5297874293 (Total skips: 17401)
# --------------------------------------------
# 🔍Checking match NA1_5297874294...
# ⚠️ NA1_5297874294 already scanned or skipped.
# 	⚠️Skipped NA1_5297874294 (Total skips: 17402)
# --------------------------------------------
# 🔍Checking match NA1_5297874295...
# ⚠️ NA1_5297874295 already scanned or skipped.
# 	⚠️Skipped NA1_5297874295 (Total skips: 17403)
# --------------------------------------------
# 🔍Checking match NA1_5297874296...
# ⚠️ NA1_5297874296 already scanned or skipped.
# 	⚠️Skipped NA1_5297874296 (Total skips: 17404)
# --------------------------------------------
# 🔍Checking match NA1_5297874297...
# ⚠️ NA1_5297874297 already scanned or skipped.
# 	⚠️Skipped NA1_5297874297 (Total skips: 17405)
# --------------------------------------------
# 🔍Checking match NA1_5297874298...
# ⚠️ NA1_5297874298 already scanned or skipped.
# 	⚠️Skipped NA1_5297874298 (Total skips: 17406)
# --------------------------------------------
# 🔍Checking match NA1_5297874299...
# ⚠️ NA1_5297874299 already scanned or skipped.
# 	⚠️Skipped NA1_5297874299 (Total skips: 17407)
# --------------------------------------------
# 🔍Checking match NA1_5297874300...
# ⚠️ NA1_5297874300 already scanned or skipped.
# 	⚠️Skipped NA1_5297874300 (Total skips: 17408)
# --------------------------------------------
# 🔍Checking match NA1_5297874301...
# ⚠️ NA1_5297874301 already scanned or skipped.
# 	⚠️Skipped NA1_5297874301 (Total skips: 17409)
# --------------------------------------------
# 🔍Checking match NA1_5297874302...
# ⚠️ NA1_5297874302 already scanned or skipped.
# 	⚠️Skipped NA1_5297874302 (Total skips: 17410)
# --------------------------------------------
# 🔍Checking match NA1_5297874303...
# ⚠️ NA1_5297874303 already scanned or skipped.
# 	⚠️Skipped NA1_5297874303 (Total skips: 17411)
# --------------------------------------------
# 🔍Checking match NA1_5297874304...
# ⚠️ NA1_5297874304 already scanned or skipped.
# 	⚠️Skipped NA1_5297874304 (Total skips: 17412)
# --------------------------------------------
# 🔍Checking match NA1_5297874305...
# ⚠️ NA1_5297874305 already scanned or skipped.
# 	⚠️Skipped NA1_5297874305 (Total skips: 17413)
# --------------------------------------------
# 🔍Checking match NA1_5297874306...
# ⚠️ NA1_5297874306 already scanned or skipped.
# 	⚠️Skipped NA1_5297874306 (Total skips: 17414)
# --------------------------------------------
# 🔍Checking match NA1_5297874307...
# ⚠️ NA1_5297874307 already scanned or skipped.
# 	⚠️Skipped NA1_5297874307 (Total skips: 17415)
# --------------------------------------------
# 🔍Checking match NA1_5297874308...
# ⚠️ NA1_5297874308 already scanned or skipped.
# 	⚠️Skipped NA1_5297874308 (Total skips: 17416)
# --------------------------------------------
# 🔍Checking match NA1_5297874309...
# ⚠️ NA1_5297874309 already scanned or skipped.
# 	⚠️Skipped NA1_5297874309 (Total skips: 17417)
# --------------------------------------------
# 🔍Checking match NA1_5297874310...
# ⚠️ NA1_5297874310 already scanned or skipped.
# 	⚠️Skipped NA1_5297874310 (Total skips: 17418)
# --------------------------------------------
# 🔍Checking match NA1_5297874311...
# ⚠️ NA1_5297874311 already scanned or skipped.
# 	⚠️Skipped NA1_5297874311 (Total skips: 17419)
# --------------------------------------------
# 🔍Checking match NA1_5297874312...
# ⚠️ NA1_5297874312 already scanned or skipped.
# 	⚠️Skipped NA1_5297874312 (Total skips: 17420)
# --------------------------------------------
# 🔍Checking match NA1_5297874313...
# ⚠️ NA1_5297874313 already scanned or skipped.
# 	⚠️Skipped NA1_5297874313 (Total skips: 17421)
# --------------------------------------------
# 🔍Checking match NA1_5297874314...
# ⚠️ NA1_5297874314 already scanned or skipped.
# 	⚠️Skipped NA1_5297874314 (Total skips: 17422)
# --------------------------------------------
# 🔍Checking match NA1_5297874315...
# ⚠️ NA1_5297874315 already scanned or skipped.
# 	⚠️Skipped NA1_5297874315 (Total skips: 17423)
# --------------------------------------------
# 🔍Checking match NA1_5297874316...
# ⚠️ NA1_5297874316 already scanned or skipped.
# 	⚠️Skipped NA1_5297874316 (Total skips: 17424)
# --------------------------------------------
# 🔍Checking match NA1_5297874317...
# ⚠️ NA1_5297874317 already scanned or skipped.
# 	⚠️Skipped NA1_5297874317 (Total skips: 17425)
# --------------------------------------------
# 🔍Checking match NA1_5297874318...
# ⚠️ NA1_5297874318 already scanned or skipped.
# 	⚠️Skipped NA1_5297874318 (Total skips: 17426)
# --------------------------------------------
# 🔍Checking match NA1_5297874319...
# ⚠️ NA1_5297874319 already scanned or skipped.
# 	⚠️Skipped NA1_5297874319 (Total skips: 17427)
# --------------------------------------------
# 🔍Checking match NA1_5297874320...
# ⚠️ NA1_5297874320 already scanned or skipped.
# 	⚠️Skipped NA1_5297874320 (Total skips: 17428)
# --------------------------------------------
# 🔍Checking match NA1_5297874321...
# ⚠️ NA1_5297874321 already scanned or skipped.
# 	⚠️Skipped NA1_5297874321 (Total skips: 17429)
# --------------------------------------------
# 🔍Checking match NA1_5297874322...
# ⚠️ NA1_5297874322 already scanned or skipped.
# 	⚠️Skipped NA1_5297874322 (Total skips: 17430)
# --------------------------------------------
# 🔍Checking match NA1_5297874323...
# ⚠️ NA1_5297874323 already scanned or skipped.
# 	⚠️Skipped NA1_5297874323 (Total skips: 17431)
# --------------------------------------------
# 🔍Checking match NA1_5297874324...
# ⚠️ NA1_5297874324 already scanned or skipped.
# 	⚠️Skipped NA1_5297874324 (Total skips: 17432)
# --------------------------------------------
# 🔍Checking match NA1_5297874325...
# ⚠️ NA1_5297874325 already scanned or skipped.
# 	⚠️Skipped NA1_5297874325 (Total skips: 17433)
# --------------------------------------------
# 🔍Checking match NA1_5297874326...
# ⚠️ NA1_5297874326 already scanned or skipped.
# 	⚠️Skipped NA1_5297874326 (Total skips: 17434)
# --------------------------------------------
# 🔍Checking match NA1_5297874327...
# ⚠️ NA1_5297874327 already scanned or skipped.
# 	⚠️Skipped NA1_5297874327 (Total skips: 17435)
# --------------------------------------------
# 🔍Checking match NA1_5297874328...
# ⚠️ NA1_5297874328 already scanned or skipped.
# 	⚠️Skipped NA1_5297874328 (Total skips: 17436)
# --------------------------------------------
# 🔍Checking match NA1_5297874329...
# ⚠️ NA1_5297874329 already scanned or skipped.
# 	⚠️Skipped NA1_5297874329 (Total skips: 17437)
# --------------------------------------------
# 🔍Checking match NA1_5297874330...
# ⚠️ NA1_5297874330 already scanned or skipped.
# 	⚠️Skipped NA1_5297874330 (Total skips: 17438)
# --------------------------------------------
# 🔍Checking match NA1_5297874331...
# ⚠️ NA1_5297874331 already scanned or skipped.
# 	⚠️Skipped NA1_5297874331 (Total skips: 17439)
# --------------------------------------------
# 🔍Checking match NA1_5297874332...
# ⚠️ NA1_5297874332 already scanned or skipped.
# 	⚠️Skipped NA1_5297874332 (Total skips: 17440)
# --------------------------------------------
# 🔍Checking match NA1_5297874333...
# ⚠️ NA1_5297874333 already scanned or skipped.
# 	⚠️Skipped NA1_5297874333 (Total skips: 17441)
# --------------------------------------------
# 🔍Checking match NA1_5297874334...
# ⚠️ NA1_5297874334 already scanned or skipped.
# 	⚠️Skipped NA1_5297874334 (Total skips: 17442)
# --------------------------------------------
# 🔍Checking match NA1_5297874335...
# ⚠️ NA1_5297874335 already scanned or skipped.
# 	⚠️Skipped NA1_5297874335 (Total skips: 17443)
# --------------------------------------------
# 🔍Checking match NA1_5297874336...
# ⚠️ NA1_5297874336 already scanned or skipped.
# 	⚠️Skipped NA1_5297874336 (Total skips: 17444)
# --------------------------------------------
# 🔍Checking match NA1_5297874337...
# ⚠️ NA1_5297874337 already scanned or skipped.
# 	⚠️Skipped NA1_5297874337 (Total skips: 17445)
# --------------------------------------------
# 🔍Checking match NA1_5297874338...
# ⚠️ NA1_5297874338 already scanned or skipped.
# 	⚠️Skipped NA1_5297874338 (Total skips: 17446)
# --------------------------------------------
# 🔍Checking match NA1_5297874339...
# ⚠️ NA1_5297874339 already scanned or skipped.
# 	⚠️Skipped NA1_5297874339 (Total skips: 17447)
# --------------------------------------------
# 🔍Checking match NA1_5297874340...
# ⚠️ NA1_5297874340 already scanned or skipped.
# 	⚠️Skipped NA1_5297874340 (Total skips: 17448)
# --------------------------------------------
# 🔍Checking match NA1_5297874341...
# ⚠️ NA1_5297874341 already scanned or skipped.
# 	⚠️Skipped NA1_5297874341 (Total skips: 17449)
# --------------------------------------------
# 🔍Checking match NA1_5297874342...
# ⚠️ NA1_5297874342 already scanned or skipped.
# 	⚠️Skipped NA1_5297874342 (Total skips: 17450)
# --------------------------------------------
# 🔍Checking match NA1_5297874343...
# ⚠️ NA1_5297874343 already scanned or skipped.
# 	⚠️Skipped NA1_5297874343 (Total skips: 17451)
# --------------------------------------------
# 🔍Checking match NA1_5297874344...
# ⚠️ NA1_5297874344 already scanned or skipped.
# 	⚠️Skipped NA1_5297874344 (Total skips: 17452)
# --------------------------------------------
# 🔍Checking match NA1_5297874345...
# ⚠️ NA1_5297874345 already scanned or skipped.
# 	⚠️Skipped NA1_5297874345 (Total skips: 17453)
# --------------------------------------------
# 🔍Checking match NA1_5297874346...
# ⚠️ NA1_5297874346 already scanned or skipped.
# 	⚠️Skipped NA1_5297874346 (Total skips: 17454)
# --------------------------------------------
# 🔍Checking match NA1_5297874347...
# ⚠️ NA1_5297874347 already scanned or skipped.
# 	⚠️Skipped NA1_5297874347 (Total skips: 17455)
# --------------------------------------------
# 🔍Checking match NA1_5297874348...
# ⚠️ NA1_5297874348 already scanned or skipped.
# 	⚠️Skipped NA1_5297874348 (Total skips: 17456)
# --------------------------------------------
# 🔍Checking match NA1_5297874349...
# ⚠️ NA1_5297874349 already scanned or skipped.
# 	⚠️Skipped NA1_5297874349 (Total skips: 17457)
# --------------------------------------------
# 🔍Checking match NA1_5297874350...
# ⚠️ NA1_5297874350 already scanned or skipped.
# 	⚠️Skipped NA1_5297874350 (Total skips: 17458)
# --------------------------------------------
# 🔍Checking match NA1_5297874351...
# ⚠️ NA1_5297874351 already scanned or skipped.
# 	⚠️Skipped NA1_5297874351 (Total skips: 17459)
# --------------------------------------------
# 🔍Checking match NA1_5297874352...
# ⚠️ NA1_5297874352 already scanned or skipped.
# 	⚠️Skipped NA1_5297874352 (Total skips: 17460)
# --------------------------------------------
# 🔍Checking match NA1_5297874353...
# ⚠️ NA1_5297874353 already scanned or skipped.
# 	⚠️Skipped NA1_5297874353 (Total skips: 17461)
# --------------------------------------------
# 🔍Checking match NA1_5297874354...
# ⚠️ NA1_5297874354 already scanned or skipped.
# 	⚠️Skipped NA1_5297874354 (Total skips: 17462)
# --------------------------------------------
# 🔍Checking match NA1_5297874355...
# ⚠️ NA1_5297874355 already scanned or skipped.
# 	⚠️Skipped NA1_5297874355 (Total skips: 17463)
# --------------------------------------------
# 🔍Checking match NA1_5297874356...
# ⚠️ NA1_5297874356 already scanned or skipped.
# ...
# 	🔍Getting Summoner for PUUID: b-9NrBFK8IHYzVrOHGkdFd08Zlr96ANTmSGfxEbQzoCcoab2GKLnKOIeNbTehcur5HamJoBFAHQZCw
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 11:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 6:60
# 	🔍Getting Rank info for Summoner oiWcr194UmmZz1B-0bpOdBitORwE0XxiXGrXqrigm5dcKys...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 12:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 6:60
# 		⚠️Failed to get rank for b-9NrBFK8IHYzVrOHGkdFd08Zlr96ANTmSGfxEbQzoCcoab2GKLnKOIeNbTehcur5HamJoBFAHQZCw:
# 		'NoneType' object does not support item assignment
# 	🔍Getting Summoner for PUUID: XgPbe-5RePJRDs_15Dukm1zHEfRQQue8stEhSKeijY01O-rRtie1ZSIK3WORvyzSNBHmyq58vREHWw
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 13:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 7:60
# 	🔍Getting Rank info for Summoner TPvRf-WC55Y3goRn1PaUR49Vb89gBjy-l7KIIPwKgAX-W6yK...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 14:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 7:60
# 		⚠️Failed to get rank for XgPbe-5RePJRDs_15Dukm1zHEfRQQue8stEhSKeijY01O-rRtie1ZSIK3WORvyzSNBHmyq58vREHWw:
# 		'NoneType' object does not support item assignment
# 	🔍Getting Summoner for PUUID: aPXkri0-hT1znNodXy85IhD4DV_f1VE8_E_wEGN24lrsbU2UZAH4-2N8uCND2lzq7t3xg0K8OgANNQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 15:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 8:60
# 	🔍Getting Rank info for Summoner wUI0eO0Jp97eXsAwsAir1sVB2heEhkC69PHBth9dDRi66ymm9I8BlK4Y_A...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 16:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 8:60
# 		⚠️Failed to get rank for aPXkri0-hT1znNodXy85IhD4DV_f1VE8_E_wEGN24lrsbU2UZAH4-2N8uCND2lzq7t3xg0K8OgANNQ:
# 		'NoneType' object does not support item assignment
# ✅Saved data\NA1_5297880187.json
# --------------------------------------------
# 🔍Checking match NA1_5297880188...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 21:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 1:10
# 	⚠️Skipped NA1_5297880188 (Total skips: 1)
# --------------------------------------------
# 🔍Checking match NA1_5297880189...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 22:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 2:10
# 	⚠️Skipped NA1_5297880189 (Total skips: 2)
# --------------------------------------------
# 🔍Checking match NA1_5297880190...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 23:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 3:10
# 	⚠️Skipped NA1_5297880190 (Total skips: 3)
# --------------------------------------------
# 🔍Checking match NA1_5297880191...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 24:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 4:10
# 	⚠️Skipped NA1_5297880191 (Total skips: 4)
# --------------------------------------------
# 🔍Checking match NA1_5297880192...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 25:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 5:10
# 	🔍Getting Summoner for PUUID: OvvvQlDEny1yDCLpNdMzeSlg0L-tsr7XDioVbx_Q0Bla5GOCU-CziKE7H0V3u1RH9UaTENB3Yi-n_w
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 17:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 9:60
# 	🔍Getting Rank info for Summoner SqQzIqk-xP_FuLTjyg2jp6YknmPvA4Ue1Z-GerYze-eWfZ8...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 18:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 9:60
# 	🔍Getting Summoner for PUUID: fmc2V-VFzvXq0MQMnf3lJ512DbBdMiFl29Et9Kb71lHqSm7704cMDoAF4XURJHbnW-A7FYbRh_X5mg
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 19:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 10:60
# 	🔍Getting Rank info for Summoner ncw2SFJB5EE-XvmzOyOTgNCOrlUSqkrwu0GS53D6GBPuSbw...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 20:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 10:60
# 	🔍Getting Summoner for PUUID: zDB0I0ideg0QlbBFKpvfY0rV_1cfFczLg6I79n-HA16b6E4yVxoB1yWNXhRlvbn7YrlR18N7ZRVcjQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 21:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 11:60
# 	🔍Getting Rank info for Summoner ZNpSVXVK8GbjmkwHu_c8f5Azy2IpDRegzW2i2n5zx9DMCbsC4xxa30z7mg...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 22:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 11:60
# 	🔍Getting Summoner for PUUID: RbBrhLtv-LL5KYJWSBxHB4xz-Jj-eMLVyUDrA8AHRlJSRXhRhLcPVynvtYWJvPAilIIPME5G1D1HTA
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 23:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 12:60
# 	🔍Getting Rank info for Summoner D38gqf5ljTgkYVhbN3liEOpIy7zUyju_MW27JM8rTVDH9Ys...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 24:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 12:60
# 	🔍Getting Summoner for PUUID: awxvpWCoQVYIUrzuXAtLRFRsJjhrQ0hmu6Og5fFp4c-P-y_vvc97wzYe0v0zkqDWYpakF5_E2bThGQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 25:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 13:60
# 	🔍Getting Rank info for Summoner rmdTg88A8xPQT25AwfBnHk7SnJHjzud-sRoQ4n2QhXbVkGc...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 26:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 13:60
# 	🔍Getting Summoner for PUUID: Gwi5PRh8QTFs4ovEe5AVmH1Uyw_ZUzoQM2AVqohpMVIjrtcAjNEcNRrXihraAnzsdVF8LNQp0grSQQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 27:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 14:60
# 	🔍Getting Rank info for Summoner RfKmTY8UgBBBTyTLgt4dtvdj_SDAF_6HjAb6UNsvAdB5-OA...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 28:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 14:60
# 	🔍Getting Summoner for PUUID: KJ9Eu1pF97DsNgwCofQSGVNHJLve9ML7Fihjm9eM6orkw_nHbfhtKNZnYFM4YbEf6Y9OTJ_cQftLVw
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 29:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 15:60
# 	🔍Getting Rank info for Summoner uXt_JK2GpEi8CFiLULyDwHC4BJDK-Mv3RXmdoDJ97IsqFryv...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 30:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 15:60
# 	🔍Getting Summoner for PUUID: Ie_5HuMWf_hmek1d1g2Btbsrc-BwM1E9Lo6v-IJWmVyIAN3l1EergrK0blCJT8tIi_qP7wa2EdrMjQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 31:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 16:60
# 	🔍Getting Rank info for Summoner rRbbX754GkmmCF9F22Qm-EF8aiUsmoaMxYJFeNzsUMq-rRXb...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 32:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 16:60
# ✅Saved data\NA1_5297880192.json
# --------------------------------------------
# 🔍Checking match NA1_5297880193...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 26:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 1:10
# 	⚠️Skipped NA1_5297880193 (Total skips: 1)
# --------------------------------------------
# 🔍Checking match NA1_5297880194...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 27:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 2:10
# 	⚠️Skipped NA1_5297880194 (Total skips: 2)
# --------------------------------------------
# 🔍Checking match NA1_5297880195...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 28:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 3:10
# 	⚠️Skipped NA1_5297880195 (Total skips: 3)
# --------------------------------------------
# 🔍Checking match NA1_5297880196...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 29:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 4:10
# 	⚠️Skipped NA1_5297880196 (Total skips: 4)
# --------------------------------------------
# 🔍Checking match NA1_5297880197...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 30:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 5:10
# 	⚠️Skipped NA1_5297880197 (Total skips: 5)
# --------------------------------------------
# 🔍Checking match NA1_5297880198...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 31:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 6:10
# 	⚠️Skipped NA1_5297880198 (Total skips: 6)
# --------------------------------------------
# 🔍Checking match NA1_5297880199...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 32:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 7:10
# 	🔍Getting Summoner for PUUID: CFPxMBmzqk0LzBu8Bh4aAgfeUTVstjn_BZF3RxIJNuOMYfkX1c1jWr90tz56keQt7oUyP-_2fAt42w
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 33:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 17:60
# 	🔍Getting Rank info for Summoner uT9rg0mt1jkqgn_5W2g87m0kn0d01QK8QqzixuBw-RPJy6w...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 34:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 17:60
# 	🔍Getting Summoner for PUUID: 0VaX63M_KhX04txv3mYQL2IraHxhRQ8J-pc-vvyu2ZrKiRYeMPxDWqJM30aXFpMWmBD7yQUbLEkyMg
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 35:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 18:60
# 	🔍Getting Rank info for Summoner IPjidSmEIO8JKoODCK27Xx7RucwBBt-pzpUPWnpg8EtLDkE...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 36:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 18:60
# 	🔍Getting Summoner for PUUID: vDfDwQ6wDNPsBmILyhHV2Msh4ICgtlVK_VnzBk9jsdM5hQsQrKlPojVu4OeSZLLrHPMfRY3dDiwUfQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 37:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 19:60
# 	🔍Getting Rank info for Summoner tAs3s1J5V97u4iBOohqXk8jS0BFy3ZhC6BCMfmFlRQYs0GQ...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 38:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 19:60
# 	🔍Getting Summoner for PUUID: PQwSk_FapRtbzc7sv5RKkjQ8GHnoQhvuvROkchZEcalNgl7dWECoze4QPr1dbvXCrhVOT0iJL9F3BQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 39:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 20:60
# 	🔍Getting Rank info for Summoner OaeprjRLl94MLESTvVdToNC6g9SXk8ItKpoUUwcFFH81bCg...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 40:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 20:60
# 	🔍Getting Summoner for PUUID: BVMBTZeF-KmNYT3Fgn8xoSzyV_INQrvzlL_RrJA6MI4XaPPup522UdM4qHTD9yP3VRPOrqENE3zw2Q
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 41:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 21:60
# 	🔍Getting Rank info for Summoner stUSbUZ7mXjHdeNDy8dQP_9RfP3u2Ydq4rLYZejebp0kXBc...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 42:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 21:60
# 	🔍Getting Summoner for PUUID: d58h9HdoIi1xtIo_maOmTb__JUbQW1yeJqPAk6Uw-_ha7er8C5BZHCMgjwC0EhsUwcVTYtyz-trhPw
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 43:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 22:60
# 	🔍Getting Rank info for Summoner nzO7J0oVLP_306ZFHIcoyCFUNGu3ppt-9Z5_hdn42mmWmyI...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 44:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 22:60
# 	🔍Getting Summoner for PUUID: mataEYaH5UNxXwe4cWdADJr8VDkTTf-Eq_-2BGtTGGlLtYxTBuGNWXwR6CepdRkTwUWai1DlJqGT0Q
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 45:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 1:60
# 	🔍Getting Rank info for Summoner 0dmxuGssBtX_MJhNS6WUeAE3213TmjFA_QNu5hRmHmFzTzfC...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 46:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 1:60
# 	🔍Getting Summoner for PUUID: gmIu5EzVyjVnMlVjxTWcSR3znL9udTDkTD8jm2SB1KoB4M4yPSPnLbPA9FMcGscCTvPZuzTV_aAaSg
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 47:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 2:60
# 	🔍Getting Rank info for Summoner 57LOYl3MGj0nxUr20yLVz2Ow7iqb4FmRz_fqI8JyiZvGvjIVUoNkY718Uw...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 48:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 2:60
# ✅Saved data\NA1_5297880199.json
# --------------------------------------------
# 🔍Checking match NA1_5297880200...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 33:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 1:10
# 	⚠️Skipped NA1_5297880200 (Total skips: 1)
# --------------------------------------------
# 🔍Checking match NA1_5297880201...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 34:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 2:10
# 	⚠️Skipped NA1_5297880201 (Total skips: 2)
# --------------------------------------------
# 🔍Checking match NA1_5297880202...
# 	X-App-Rate-Limit: 100:120,20:1
# 	X-App-Rate-Limit-Count: 35:120,1:1
# 	X-Method-Rate-Limit: 200:10
# 	X-Method-Rate-Limit-Count: 3:10
# 	🔍Getting Summoner for PUUID: JF2_rEMzEbLEzyLaQUgi4IzbxQ3HkwfRcfKe4ZyypvAHm10SjwZVGMGbePYyg3CsHJjzHZ6FfVCnIA
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 49:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 3:60
# 	🔍Getting Rank info for Summoner gFP9o-YfLAorls_pfeVkSRuO9wqvJxwD-VQ0vHJqY6yrXS816xMBzrphpg...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 50:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 3:60
# 	🔍Getting Summoner for PUUID: x0JiL5UfYJKP4E_tigpi47j0SQL_B0csHGOVQ0TB-e91xQQTrggZHAoqMurZjh9ijNZu0jRGIHUEuQ
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 51:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 4:60
# 	🔍Getting Rank info for Summoner 2iEM7jfBNffXzRFBL37RpmZcdXHY8W4-QA8UCSXk42dWo2p6Zys-qaCq5g...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 52:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 4:60
# 	🔍Getting Summoner for PUUID: vXtb_-PT9dRjpxiN7YvB4m4w8DrnPJBkfAONOB3jSnFFioRsub047s3lc54NyRjkjQ38HVjtvHy47A
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 53:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 5:60
# 	🔍Getting Rank info for Summoner XCTPq0lDf4hTvybJoMy-hb9b6v5Vb0AtCMwe6BPyIgwHay8...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 54:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 5:60
# 	🔍Getting Summoner for PUUID: 0oOeC8mfDxE6LDVA_E9LQgbRqc7SJG_4-82SoHiuh4O48k4zpvTioRaOtnrEv4jR34z36eJrjsC10Q
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 55:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 6:60
# 	🔍Getting Rank info for Summoner GMxjCJ0uSsLzMBJhG2ZjT-R3DWCsP9Hho5u32AeNhPfJvqE...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 56:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 6:60
# 	🔍Getting Summoner for PUUID: d6Umd0bb8EsKeRIkJFSm2Jih2wFbqQ0D8FjGLCGtJ7uvP2Bpb7nOsbvwgTq4mopuEGpZWSWy1v7rHw
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 57:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 7:60
# 	🔍Getting Rank info for Summoner XR_gJt60xUUhr3UicYgSVjDxUrAvufnVm2RAlG5IKA_Gu2Y...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 58:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 7:60
# 	🔍Getting Summoner for PUUID: GFNsC-ORUPNFC1LKIqceebNuOzUr42o8MUOZI_M2hImpsbYKhi_9JvesI8PGikuBPTtWdGx1RkMH7w
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 59:120,1:1
# 		X-Method-Rate-Limit: 2000:60
# 		X-Method-Rate-Limit-Count: 8:60
# 	🔍Getting Rank info for Summoner mfWDAHba3M_xi6Kvm8tbZBGRnI6kosyur3TA9V3CmyfCfRc...
# 		X-App-Rate-Limit: 100:120,20:1
# 		X-App-Rate-Limit-Count: 60:120,1:1
# 		X-Method-Rate-Limit: 270:60
# 		X-Method-Rate-Limit-Count: 8:60
# 	🔍Getting Summoner for PUUID: vEKwB-sONB-7ylm1LbFWonIE0lZMmbgyw0Ft35VXb5_yRfof9MImqOblajBhJgkyL1-RSHacxGUl9A
