# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import json
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import multiprocessing

from scipy.stats import randint

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.tree import DecisionTreeRegressor, plot_tree

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV

import tftinsights
from tftinsights.data import get_tft_dataset

# %% [markdown]
# # Placement Regression
#
# In this notebook, we'll aim to build a regression model for a certain composition
# The goal is to extract information about what influnces win rates, and to determien if we need to feature engineer anything.

# %%
multiprocessing.cpu_count()
# Out:
# 16

# %%
CORE_UNTOUCHED = 3
CORE_TO_USE = max (1, multiprocessing.cpu_count()-CORE_UNTOUCHED)

# %%
df = tftinsights.data.get_tft_dataset(include_traits  =True, include_units =True, include_items=False,include_player_data=False)

# %%
def TFTDecisionTreeRegression ( df ):
    import numpy as np
    from sklearn.tree import DecisionTreeRegressor
    from sklearn.model_selection import RandomizedSearchCV, KFold
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
    from scipy.stats import randint, uniform
    import warnings
    import multiprocessing # my CPU > GPU

    y = df['placement'].astype(float) #dependent variable
    x = df.drop(columns='placement')    #independent variables 
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3126)

    param_distributions = {
        'max_depth': randint(5, 700), 
        'min_samples_split': uniform(0.1,0.7), 
        'min_samples_leaf': randint(1, 500) 
    }
        
    model = DecisionTreeRegressor(random_state=3126)
        
    search = RandomizedSearchCV(
        estimator=model,
        param_distributions=param_distributions,
        n_iter=300,
        scoring='neg_root_mean_squared_error',
        cv=5,
        random_state=42,
        verbose=1,
        n_jobs=-CORE_TO_USE #I would like to do things while it's processing
    )
    
    search.fit(x_train, y_train)
        
    best_model = search.best_estimator_
    best_params = search.best_params_
    print("\nBest Params:", best_params)
    
    y_pred = best_model.predict(x_test)
        
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\nModel Evaluation:")
    print(f"MAE: {mae:.4f}")
    print(f"MSE: {mse:.4f}")
    print(f"R²:  {r2:.4f}")

    return search

# %% [markdown]
# ## Placement Regression: Traits + Units

# %%
search = TFTDecisionTreeRegression ( df )
# Out:
# (68376, 92)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 489, 'min_samples_leaf': 28, 'min_samples_split': 0.11404983844440847}
#
# Model Evaluation:
# MAE: 1.5385
# MSE: 3.4921
# R²:  0.3318

# %% [raw]
# (140216, 86)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}
#
# Model Evaluation:
# MAE: 1.5497
# MSE: 3.5166
# R²:  0.3281
#
# Let's take a look what the tree is looking at.

# %%
from sklearn.tree import export_text
x = df.drop(columns='placement')    #independent variables 
best_tree = search.best_estimator_
tree_rules = export_text(best_tree, feature_names=x.columns.tolist())
print(tree_rules)
# Out:
# |--- unit_TFT14_Aurora <= 1.50
# |   |--- unit_TFT14_Kobuko <= 1.50
# |   |   |--- unit_TFT14_Renekton <= 1.50
# |   |   |   |--- unit_TFT14_Samira <= 1.50
# |   |   |   |   |--- unit_TFT14_SummonLevel4 <= 2.00
# |   |   |   |   |   |--- unit_TFT14_Leona <= 1.50
# |   |   |   |   |   |   |--- trait_TFT14_Bruiser <= 0.50
# |   |   |   |   |   |   |   |--- unit_TFT14_Sejuani <= 1.50
# |   |   |   |   |   |   |   |   |--- unit_TFT14_Neeko <= 1.50
# |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Jarvan <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- trait_TFT14_Armorclad <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- trait_TFT14_Armorclad >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [5.17]
# |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Jarvan >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [5.43]
# |   |   |   |   |   |   |   |   |--- unit_TFT14_Neeko >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [4.87]
# |   |   |   |   |   |   |   |--- unit_TFT14_Sejuani >  1.50
# |   |   |   |   |   |   |   |   |--- value: [4.53]
# |   |   |   |   |   |   |--- trait_TFT14_Bruiser >  0.50
# |   |   |   |   |   |   |   |--- unit_TFT14_Braum <= 2.50
# |   |   |   |   |   |   |   |   |--- unit_TFT14_Viego <= 1.50
# |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Zed <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Urgot <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Urgot >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [3.45]
# |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Zed >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [3.98]
# |   |   |   |   |   |   |   |   |--- unit_TFT14_Viego >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [3.17]
# |   |   |   |   |   |   |   |--- unit_TFT14_Braum >  2.50
# |   |   |   |   |   |   |   |   |--- value: [3.39]
# |   |   |   |   |   |--- unit_TFT14_Leona >  1.50
# |   |   |   |   |   |   |--- value: [4.26]
# |   |   |   |   |--- unit_TFT14_SummonLevel4 >  2.00
# |   |   |   |   |   |--- value: [3.51]
# |   |   |   |--- unit_TFT14_Samira >  1.50
# |   |   |   |   |--- value: [3.04]
# |   |   |--- unit_TFT14_Renekton >  1.50
# |   |   |   |--- value: [2.87]
# |   |--- unit_TFT14_Kobuko >  1.50
# |   |   |--- value: [2.75]
# |--- unit_TFT14_Aurora >  1.50
# |   |--- value: [2.62]

# %%
plt.figure(figsize=(20, 10))  # Adjust size as needed
plot_tree(
    best_tree,
    feature_names=x.columns,
    class_names=True,  # or provide class names if it's classification
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %% [raw]
# Raw save of above
#
# |--- unit_TFT14_Kobuko <= 1.50
# |   |--- unit_TFT14_Aurora <= 1.50
# |   |   |--- unit_TFT14_Samira <= 1.50
# |   |   |   |--- unit_TFT14_Renekton <= 1.50
# |   |   |   |   |--- unit_TFT14_Braum <= 2.50
# |   |   |   |   |   |--- unit_TFT14_Viego <= 1.50
# |   |   |   |   |   |   |--- unit_TFT14_Neeko <= 1.50
# |   |   |   |   |   |   |   |--- unit_TFT14_Leona <= 1.50
# |   |   |   |   |   |   |   |   |--- unit_TFT14_Sejuani <= 1.50
# |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Chogath <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Zed <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 30
# |   |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Zed >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [4.42]
# |   |   |   |   |   |   |   |   |   |--- unit_TFT14_Chogath >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [4.43]
# |   |   |   |   |   |   |   |   |--- unit_TFT14_Sejuani >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [4.45]
# |   |   |   |   |   |   |   |--- unit_TFT14_Leona >  1.50
# |   |   |   |   |   |   |   |   |--- value: [4.39]
# |   |   |   |   |   |   |--- unit_TFT14_Neeko >  1.50
# |   |   |   |   |   |   |   |--- value: [4.34]
# |   |   |   |   |   |--- unit_TFT14_Viego >  1.50
# |   |   |   |   |   |   |--- value: [3.41]
# |   |   |   |   |--- unit_TFT14_Braum >  2.50
# |   |   |   |   |   |--- value: [3.36]
# |   |   |   |--- unit_TFT14_Renekton >  1.50
# |   |   |   |   |--- value: [3.12]
# |   |   |--- unit_TFT14_Samira >  1.50
# |   |   |   |--- value: [2.78]
# |   |--- unit_TFT14_Aurora >  1.50
# |   |   |--- value: [2.87]
# |--- unit_TFT14_Kobuko >  1.50
# |   |--- value: [2.57]

# %% [markdown]
# # As you can see, the regression here is pretty weak since at about 0.35ish for R2.
# # Taking a look at the decision tree breakdown, we can see it is just splitting off and looking at unit the player have (at a float, why not int?)
# # So this probably indicates we should do some amount of feature engineering to just group up the number of units by cost.

# %% [markdown]
# Before we do feature engineering, lets see what set of information is sufficent for the regression;
#
# Traits,
# Units
# Items
#
# Or what combination of it works best,

# %% [markdown]
# ## Placement Regression: Traits ONLY

# %%
df = tftinsights.data.get_tft_dataset(include_traits=True, include_units=False, include_items=False, include_player_data=False)  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (140216, 26)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}

# Model Evaluation:
# MAE: 1.7771
# MSE: 4.4129
# Out:
# (68376, 29)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 381, 'min_samples_leaf': 289, 'min_samples_split': 0.10527405419385233}
#
# Model Evaluation:
# MAE: 1.8017
# MSE: 4.4916
# R²:  0.1405
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B1016C0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B101780>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B1037C0>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (140216, 26)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}
#
# Model Evaluation:
# MAE: 1.7771
# MSE: 4.4129
# R²:  0.1568

# %% [markdown]
# ## Placement Regression: Units ONLY

# %%
df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False)  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (68376, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 489, 'min_samples_leaf': 28, 'min_samples_split': 0.11404983844440847}
#
# Model Evaluation:
# MAE: 1.5318
# MSE: 3.4520
# R²:  0.3395
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE37C9D8D0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE37C9D7E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE37C9FA30>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (140216, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}
#
# Model Evaluation:
# MAE: 1.5571
# MSE: 3.5369
# R²:  0.3242

# %% [markdown]
# WE got results similar to our initial regression with TRAITS + UNITS;
#
# <b>This indicates that the decision tree is able to tell the relationships between unit syngergies.</b>
#
# Meaning traits are not great for generalization.

# %% [markdown]
# ## Placement Regression: Items ONLY

# %%
df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=False, include_items=True, include_player_data=False)  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (68376, 167)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 381, 'min_samples_leaf': 289, 'min_samples_split': 0.10527405419385233}
#
# Model Evaluation:
# MAE: 1.8333
# MSE: 4.6720
# R²:  0.1060
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B42D8D0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B42D810>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B42FA00>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (140216, 165)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 555, 'min_samples_leaf': 415, 'min_samples_split': 0.10078407803607664}
#
# Model Evaluation:
# MAE: 1.8370
# MSE: 4.6879
# R²:  0.1043

# %% [markdown]
# ## Placement Regression: Units + Items

# %%
df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=True, include_player_data=False)  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (68376, 230)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}
#
# Model Evaluation:
# MAE: 1.5539
# MSE: 3.5179
# R²:  0.3269
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE37C9C1F0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE37C9D1E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE37C9DF00>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [markdown]
# Adding items units to do the regression produced no noticable results, indicatingt that units is the strongest predictor of success.
# This assumes the player is good enough to not combine bad items on the wrong unit.

# %% [markdown]
# Items placement is known to be critical in the game
# so how can we get that data, or how can  we help the model to understand that importnat?

# %% [raw]
# (68376, 11)
# Index(['cost_count_1', 'cost_count_2', 'cost_count_3', 'cost_count_4',
#        'cost_count_5', 'max_star_cost_1', 'max_star_cost_2', 'max_star_cost_3',
#        'max_star_cost_4', 'max_star_cost_5', 'placement'],
#       dtype='object')
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}
#
# Model Evaluation:
# MAE: 1.4473
# MSE: 3.1513
# R²:  0.3970

# %%
# ALL - Trait Unit Item

# %%
df = tftinsights.data.get_tft_dataset(include_traits=True, include_units=True, include_items=True, include_player_data=False)  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (68376, 258)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 489, 'min_samples_leaf': 28, 'min_samples_split': 0.11404983844440847}
#
# Model Evaluation:
# MAE: 1.5456
# MSE: 3.5123
# R²:  0.3279
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE307F9810>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE307F96F0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE307FB730>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [markdown]
# ## Model Evaluation Metrics (Sorted by R²)
#
# | Model           | MAE    | MSE    | R²     |
# |----------------|--------|--------|--------|
# | Trait + Unit   | 1.5534 | 3.5230 | 0.3269 |
# | Units Only     | 1.5571 | 3.5369 | 0.3242 |
# | Unit + Items   | 1.5639 | 3.5593 | 0.3199 |
# | Trait Only     | 1.7821 | 4.4365 | 0.1523 |
# | Items Only     | 1.8370 | 4.6879 | 0.1043 |
#
# Given the behaviors observed in our data set, Unit is the best subset predictor of Placements.
# Items isn't relevant because those that win with a composition will have nautrally required to have the correct items for it, espeically the higher the player goes up in ranking. This is something that the ML is unlikely able to interpret.
#
# Looking at the decision tree from Traits+Unit, we can see the decision branch nodes are all 5 and 4 cost units, which seems to suggest we should feature engineer # of X $ units columns - # of 1 cost unit, # of 2 cost Unit, etc etc.
#
# ## Skill Subset
#
# ### Model Evaluation by Skill Bracket
#
# | Skill Bracket | Data Points | MAE    | MSE    | R²     | Best Params                                                                 |
# |---------------|-------------|--------|--------|--------|------------------------------------------------------------------------------|
# | Iron          | 346         | 1.5158 | 2.8924 | 0.0388 | {'max_depth': 361, 'min_samples_leaf': 23, 'min_samples_split': 0.1336}     |
# | Bronze        | 3,365       | 1.4435 | 3.2218 | 0.2309 | {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170}      |
# | Silver        | 17,137      | 1.5374 | 3.4522 | 0.3315 | {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170}      |
# | Gold          | 36,992      | 1.5217 | 3.4523 | 0.3353 | {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.1036}      |
# | Platinum      | 39,138      | 1.5178 | 3.4207 | 0.3490 | {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.1036}      |
# | Emerald       | 21,570      | 1.5517 | 3.5342 | 0.3243 | {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.1007}     |
# | Diamond       | 8,620       | 1.5611 | 3.6520 | 0.3120 | {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.1036}      |
# | Master        | 3,956       | 1.5721 | 3.7097 | 0.2814 | {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.1036}      |
# | Grandmaster   | 762         | 1.6981 | 4.5149 | 0.0779 | {'max_depth': 412, 'min_samples_leaf': 13, 'min_samples_split': 0.1571}     |
# | Challenger    | 417         | 1.7013 | 4.5856 | 0.1009 | {'max_depth': 353, 'min_samples_leaf': 8, 'min_samples_split': 0.1190}      |

# %% [markdown]
# ## Placement Regression: Feature Engineered

# %%
import tftinsights
from tftinsights.data import get_tft_dataset
df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=False, include_items=False, include_engineered_features=True,include_player_data=False)  
print(df.shape)
print ( df.columns)
TFTDecisionTreeRegression ( df )
# Out:
# (68376, 14)
# Index(['cost_count_1', 'cost_count_2', 'cost_count_3', 'cost_count_4',
#        'cost_count_5', 'max_star_cost_1', 'max_star_cost_2', 'max_star_cost_3',
#        'max_star_cost_4', 'max_star_cost_5', 'eg_trait_max', 'eg_trait_count',
#        'eg_trait_average', 'placement'],
#       dtype='object')
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 489, 'min_samples_leaf': 28, 'min_samples_split': 0.11404983844440847}
#
# Model Evaluation:
# MAE: 1.4569
# MSE: 3.1724
# R²:  0.3930
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B42C1C0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B42E380>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B42EF50>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (68376, 11)
# Index(['cost_count_1', 'cost_count_2', 'cost_count_3', 'cost_count_4',
#        'cost_count_5', 'max_star_cost_1', 'max_star_cost_2', 'max_star_cost_3',
#        'max_star_cost_4', 'max_star_cost_5', 'placement'],
#       dtype='object')
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}
#
# Model Evaluation:
# MAE: 1.4473
# MSE: 3.1513
# R²:  0.3970
#
#
# Adding the traits columns
#
# (68376, 14)
# Index(['cost_count_1', 'cost_count_2', 'cost_count_3', 'cost_count_4',
#        'cost_count_5', 'max_star_cost_1', 'max_star_cost_2', 'max_star_cost_3',
#        'max_star_cost_4', 'max_star_cost_5', 'eg_trait_max', 'eg_trait_count',
#        'eg_trait_average', 'placement'],
#       dtype='object')
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}
#
# Model Evaluation:
# MAE: 1.4480
# MSE: 3.1520
# R²:  0.3969
#
# did nothign (values lookgs buggy)

# %%
import tftinsights
from tftinsights.data import get_tft_dataset
df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=False, include_items=False, include_engineered_features=True,include_player_data=False) 

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import randint, uniform
import warnings
import multiprocessing # my CPU > GPU

y = df['placement'].astype(float) #dependent variable
x = df.drop(columns='placement')    #independent variables 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3126)

param_distributions = {
    'max_depth': randint(2, 7), 
    'min_samples_split': uniform(0.1,0.7), 
    'min_samples_leaf': randint(1, 500)   
}

model = DecisionTreeRegressor(random_state=3126)

search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distributions,
    n_iter=300,
    scoring='neg_root_mean_squared_error',
    cv=5,
    random_state=42,
    verbose=1,
    n_jobs=-CORE_TO_USE
)

# Run random search
search.fit(x_train, y_train)

# Best estimator
best_model = search.best_estimator_
best_params = search.best_params_
print("\nBest Params:", best_params)

y_pred = best_model.predict(x_test)

y_pred_rounded = np.round(y_pred)
# Evaluation
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nModel Evaluation:")
print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"R²:  {r2:.4f}\n")

mae = mean_absolute_error(y_test, y_pred_rounded)
mse = mean_squared_error(y_test, y_pred_rounded)
r2 = r2_score(y_test, y_pred_rounded)

print(f"\nModel Evaluation: (Rounded")
print(f"MAE: {mae:.4f}")
print(f"MSE: {mse:.4f}")
print(f"R²:  {r2:.4f}\n")

best_tree = search.best_estimator_
tree_rules = export_text(best_tree, feature_names=x.columns.tolist())
print(tree_rules)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 6, 'min_samples_leaf': 65, 'min_samples_split': 0.11094548471883575}
#
# Model Evaluation:
# MAE: 1.4655
# MSE: 3.2031
# R²:  0.3871
#
#
# Model Evaluation: (Rounded
# MAE: 1.4469
# MSE: 3.2865
# R²:  0.3711
#
# |--- max_star_cost_5 <= 1.50
# |   |--- max_star_cost_4 <= 1.50
# |   |   |--- max_star_cost_2 <= 2.50
# |   |   |   |--- max_star_cost_1 <= 2.50
# |   |   |   |   |--- max_star_cost_3 <= 2.50
# |   |   |   |   |   |--- value: [6.75]
# |   |   |   |   |--- max_star_cost_3 >  2.50
# |   |   |   |   |   |--- value: [5.96]
# |   |   |   |--- max_star_cost_1 >  2.50
# |   |   |   |   |--- value: [6.02]
# |   |   |--- max_star_cost_2 >  2.50
# |   |   |   |--- value: [5.41]
# |   |--- max_star_cost_4 >  1.50
# |   |   |--- max_star_cost_3 <= 2.50
# |   |   |   |--- max_star_cost_1 <= 2.50
# |   |   |   |   |--- max_star_cost_4 <= 2.50
# |   |   |   |   |   |--- cost_count_2 <= 1.50
# |   |   |   |   |   |   |--- value: [5.79]
# |   |   |   |   |   |--- cost_count_2 >  1.50
# |   |   |   |   |   |   |--- value: [5.22]
# |   |   |   |   |--- max_star_cost_4 >  2.50
# |   |   |   |   |   |--- value: [1.47]
# |   |   |   |--- max_star_cost_1 >  2.50
# |   |   |   |   |--- value: [4.16]
# |   |   |--- max_star_cost_3 >  2.50
# |   |   |   |--- value: [3.53]
# |--- max_star_cost_5 >  1.50
# |   |--- max_star_cost_4 <= 2.50
# |   |   |--- max_star_cost_3 <= 2.50
# |   |   |   |--- max_star_cost_4 <= 1.50
# |   |   |   |   |--- value: [4.43]
# |   |   |   |--- max_star_cost_4 >  1.50
# |   |   |   |   |--- max_star_cost_1 <= 2.50
# |   |   |   |   |   |--- max_star_cost_1 <= 1.50
# |   |   |   |   |   |   |--- value: [3.65]
# |   |   |   |   |   |--- max_star_cost_1 >  1.50
# |   |   |   |   |   |   |--- value: [3.13]
# |   |   |   |   |--- max_star_cost_1 >  2.50
# |   |   |   |   |   |--- value: [2.51]
# |   |   |--- max_star_cost_3 >  2.50
# |   |   |   |--- value: [2.31]
# |   |--- max_star_cost_4 >  2.50
# |   |   |--- value: [1.20]

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Plot the tree
plt.figure(figsize=(20, 10))  # Adjust size as needed
plot_tree(
    best_tree,
    feature_names=x.columns,
    class_names=True,  # or provide class names if it's classification
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()

# %% [markdown]
# # Skill Subset

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="IRON")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (346, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 361, 'min_samples_leaf': 23, 'min_samples_split': 0.13364124693792362}

# Model Evaluation:
# MAE: 1.5158
# MSE: 2.8924
# R²:  0.0388
# Out:
# (116, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 628, 'min_samples_leaf': 4, 'min_samples_split': 0.6955722624853024}
#
# Model Evaluation:
# MAE: 1.6262
# MSE: 4.2432
# R²:  -0.0339
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE4F42ACE0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE4F42A9B0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B17F730>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="BRONZE")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (3365, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}

# Model Evaluation:
# MAE: 1.4435
# MSE: 3.2218
# R²:  0.2309
# Out:
# (1477, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}
#
# Model Evaluation:
# MAE: 1.4349
# MSE: 3.2386
# R²:  0.2514
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B103280>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B42F460>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B102E30>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="SILVER")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (17137, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}

# Model Evaluation:
# MAE: 1.5374
# MSE: 3.4522
# R²:  0.3315
# Out:
# (6586, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}
#
# Model Evaluation:
# MAE: 1.5032
# MSE: 3.3731
# R²:  0.3653
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B17EC80>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE374856F0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B17FD00>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="GOLD")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (36992, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.10360161952830034}

# Model Evaluation:
# MAE: 1.5217
# MSE: 3.4523
# R²:  0.3353
# Out:
# (15247, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 489, 'min_samples_leaf': 28, 'min_samples_split': 0.11404983844440847}
#
# Model Evaluation:
# MAE: 1.4951
# MSE: 3.2937
# R²:  0.3593
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B103310>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B60CA30>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B100460>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="PLATINUM")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (39138, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.10360161952830034}

# Model Evaluation:
# MAE: 1.5178
# MSE: 3.4207
# R²:  0.3490
# Out:
# (19444, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}
#
# Model Evaluation:
# MAE: 1.5175
# MSE: 3.4214
# R²:  0.3529
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B17F0A0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE4F42B370>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B1967D0>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="EMERALD")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (21570, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 463, 'min_samples_leaf': 58, 'min_samples_split': 0.10072063589194338}

# Model Evaluation:
# MAE: 1.5517
# MSE: 3.5342
# R²:  0.3243
# Out:
# (12636, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 489, 'min_samples_leaf': 28, 'min_samples_split': 0.11404983844440847}
#
# Model Evaluation:
# MAE: 1.5351
# MSE: 3.5437
# R²:  0.3020
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B60D8A0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B60F4F0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B60E110>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="DIAMOND")  
print(df.shape)
TFTDecisionTreeRegression ( df )

# (8620, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# Best Params: {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.10360161952830034}

# Model Evaluation:
# MAE: 1.5611
# MSE: 3.6520
# R²:  0.3120
# Out:
# (6164, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}
#
# Model Evaluation:
# MAE: 1.5696
# MSE: 3.6624
# R²:  0.3158
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE3869AFE0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE37486920>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE38698D60>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="MASTER")  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (3559, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 663, 'min_samples_leaf': 4, 'min_samples_split': 0.1170211765020177}
#
# Model Evaluation:
# MAE: 1.6593
# MSE: 3.9909
# R²:  0.2673
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B60FFA0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2B60D960>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2B60C5B0>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (3956, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 35, 'min_samples_leaf': 23, 'min_samples_split': 0.10360161952830034}
#
# Model Evaluation:
# MAE: 1.5721
# MSE: 3.7097
# R²:  0.2814

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER' # ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="GRANDMASTER")  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (372, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 339, 'min_samples_leaf': 30, 'min_samples_split': 0.5354606901595115}
#
# Model Evaluation:
# MAE: 1.9073
# MSE: 5.2960
# R²:  -0.1036
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE4F42B8E0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE374863E0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE4F429030>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (762, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 412, 'min_samples_leaf': 13, 'min_samples_split': 0.15711592628016824}
#
# Model Evaluation:
# MAE: 1.6981
# MSE: 4.5149
# R²:  0.0779

# %%
#def get_tft_dataset ( include_traits  =True, include_units =True, include_items =True, include_units_item=False, ranked_queue=True, include_player_data=True, rankFilter=""):
# tier_order = [
#     'IRON', 'BRONZE', 'SILVER', 'GOLD',
#     'PLATINUM', 'EMERALD', 'DIAMOND', 'MASTER', 
#     'GRANDMASTER', 'CHALLENGER'
# ]

df = tftinsights.data.get_tft_dataset(include_traits=False, include_units=True, include_items=False, include_player_data=False, rankFilter="CHALLENGER")  
print(df.shape)
TFTDecisionTreeRegression ( df )
# Out:
# (192, 64)
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#
# Best Params: {'max_depth': 53, 'min_samples_leaf': 17, 'min_samples_split': 0.7961853575581387}
#
# Model Evaluation:
# MAE: 1.7833
# MSE: 4.5477
# R²:  0.0637
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3126),
#                    n_iter=300, n_jobs=-19,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2E73E950>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001EE2E73E110>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EE2E73D7E0>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=1)

# %% [raw]
# (417, 61)
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
#
# Best Params: {'max_depth': 353, 'min_samples_leaf': 8, 'min_samples_split': 0.11896719475243844}
#
# Model Evaluation:
# MAE: 1.7013
# MSE: 4.5856
# R²:  0.1009
