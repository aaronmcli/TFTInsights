# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import json
import pandas as pd
import numpy as np
import requests
import tftinsights
import tftinsights.config
import tftinsights.units
from tqdm.notebook import tqdm

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 0)
pd.set_option('display.max_colwidth', None)

# %%
df = tftinsights.units.get_unit_list()
df
# Out:
#             name                             traits  cost  unitplannerid  \
# 0        Alistar               [Golden Ox, Bruiser]     1            786
# 51            Vi                 [Cypher, Vanguard]     1            784
# 44         Sylas            [Anima Squad, Vanguard]     1            780
# 41         Shaco                [Syndicate, Slayer]     1            752
# 40     Seraphine              [Anima Squad, Techie]     1            766
# 33         Poppy               [Cyberboss, Bastion]     1            776
# 32       Nidalee                    [Nitro, A.M.P.]     1            761
# 24       Kog'Maw              [BoomBots, Rapidfire]     1            771
# 22       Kindred       [Nitro, Rapidfire, Marksman]     1            763
# 19           Jax                 [Exotech, Bastion]     1            773
# 29       Morgana               [Divinicorp, Dynamo]     1            746
# 59          Zyra             [Street Demon, Techie]     1            759
# 9      Dr. Mundo    [Street Demon, Bruiser, Slayer]     1            739
# 10          Ekko         [Street Demon, Strategist]     2            799
# 36        Rhaast             [Divinicorp, Vanguard]     2            791
# 25       LeBlanc               [Cypher, Strategist]     2            744
# 7         Darius               [Syndicate, Bruiser]     2            738
# 42       Shyvana           [Nitro, Bastion, Techie]     2            762
# 43       Skarner               [BoomBots, Vanguard]     2            772
# 20          Jhin        [Exotech, Marksman, Dynamo]     2            768
# 17        Illaoi             [Anima Squad, Bastion]     2            765
# 16        Graves           [Golden Ox, Executioner]     2            789
# 48         Vayne              [Anima Squad, Slayer]     2            782
# 49        Veigar                [Cyberboss, Techie]     2            755
# 45  Twisted Fate             [Syndicate, Rapidfire]     2            753
# 30       Naafiri                  [Exotech, A.M.P.]     2            769
# 5          Braum              [Syndicate, Vanguard]     3            760
# 39         Senna               [Divinicorp, Slayer]     3            751
# 47         Varus             [Exotech, Executioner]     3            754
# 54         Yuumi  [Anima Squad, A.M.P., Strategist]     3            764
# 11         Elise                    [Nitro, Dynamo]     3            740
# 18     Jarvan IV      [Golden Ox, Vanguard, Slayer]     3            788
# 12  Fiddlesticks                 [BoomBots, Techie]     3            741
# 13         Galio                  [Cypher, Bastion]     3            742
# 15        Gragas              [Divinicorp, Bruiser]     3            770
# 21          Jinx           [Street Demon, Marksman]     3            798
# 8         Draven                [Cypher, Rapidfire]     3            796
# 35        Rengar        [Street Demon, Executioner]     3            749
# 28   Mordekaiser         [Exotech, Bruiser, Techie]     3            785
# 38       Sejuani                 [Exotech, Bastion]     4            775
# 57          Zeri               [Exotech, Rapidfire]     4            758
# 56           Zed                   [Cypher, Slayer]     4            757
# 6       Cho'Gath                [BoomBots, Bruiser]     4            778
# 53         Xayah            [Anima Squad, Marksman]     4            767
# 1          Annie                [Golden Ox, A.M.P.]     4            790
# 50           Vex          [Divinicorp, Executioner]     4            756
# 31         Neeko         [Street Demon, Strategist]     4            747
# 58         Ziggs            [Cyberboss, Strategist]     4            777
# 2       Aphelios              [Golden Ox, Marksman]     4           1818
# 27  Miss Fortune                [Syndicate, Dynamo]     4            745
# 26         Leona            [Anima Squad, Vanguard]     4            783
# 4          Brand             [Street Demon, Techie]     4            737
# 34      Renekton    [Overlord, Divinicorp, Bastion]     5            748
# 37        Samira             [Street Demon, A.M.P.]     5            750
# 52         Viego   [Soul Killer, Golden Ox, Techie]     5            787
# 3         Aurora              [Anima Squad, Dynamo]     5            781
# 55           Zac                            [Virus]     5            797
# 23        Kobuko               [Cyberboss, Bruiser]     5            774
# 46         Urgot            [BoomBots, Executioner]     5            779
# 14         Garen                   [God of the Net]     5            743
#
#            trait_1      trait_2     trait_3                   id
# 0        Golden Ox      Bruiser         NaN        TFT14_Alistar
# 51          Cypher     Vanguard         NaN             TFT14_Vi
# 44     Anima Squad     Vanguard         NaN          TFT14_Sylas
# 41       Syndicate       Slayer         NaN          TFT14_Shaco
# 40     Anima Squad       Techie         NaN      TFT14_Seraphine
# 33       Cyberboss      Bastion         NaN          TFT14_Poppy
# 32           Nitro       A.M.P.         NaN  TFT14_NidaleeCougar
# 24        BoomBots    Rapidfire         NaN         TFT14_KogMaw
# 22           Nitro    Rapidfire    Marksman        TFT14_Kindred
# 19         Exotech      Bastion         NaN            TFT14_Jax
# 29      Divinicorp       Dynamo         NaN        TFT14_Morgana
# 59    Street Demon       Techie         NaN           TFT14_Zyra
# 9     Street Demon      Bruiser      Slayer        TFT14_DrMundo
# 10    Street Demon   Strategist         NaN           TFT14_Ekko
# 36      Divinicorp     Vanguard         NaN         TFT14_Rhaast
# 25          Cypher   Strategist         NaN        TFT14_LeBlanc
# 7        Syndicate      Bruiser         NaN         TFT14_Darius
# 42           Nitro      Bastion      Techie        TFT14_Shyvana
# 43        BoomBots     Vanguard         NaN        TFT14_Skarner
# 20         Exotech     Marksman      Dynamo           TFT14_Jhin
# 17     Anima Squad      Bastion         NaN         TFT14_Illaoi
# 16       Golden Ox  Executioner         NaN         TFT14_Graves
# 48     Anima Squad       Slayer         NaN          TFT14_Vayne
# 49       Cyberboss       Techie         NaN         TFT14_Veigar
# 45       Syndicate    Rapidfire         NaN    TFT14_TwistedFate
# 30         Exotech       A.M.P.         NaN        TFT14_Naafiri
# 5        Syndicate     Vanguard         NaN          TFT14_Braum
# 39      Divinicorp       Slayer         NaN          TFT14_Senna
# 47         Exotech  Executioner         NaN          TFT14_Varus
# 54     Anima Squad       A.M.P.  Strategist          TFT14_Yuumi
# 11           Nitro       Dynamo         NaN          TFT14_Elise
# 18       Golden Ox     Vanguard      Slayer         TFT14_Jarvan
# 12        BoomBots       Techie         NaN   TFT14_Fiddlesticks
# 13          Cypher      Bastion         NaN          TFT14_Galio
# 15      Divinicorp      Bruiser         NaN         TFT14_Gragas
# 21    Street Demon     Marksman         NaN           TFT14_Jinx
# 8           Cypher    Rapidfire         NaN         TFT14_Draven
# 35    Street Demon  Executioner         NaN         TFT14_Rengar
# 28         Exotech      Bruiser      Techie    TFT14_Mordekaiser
# 38         Exotech      Bastion         NaN        TFT14_Sejuani
# 57         Exotech    Rapidfire         NaN           TFT14_Zeri
# 56          Cypher       Slayer         NaN            TFT14_Zed
# 6         BoomBots      Bruiser         NaN        TFT14_Chogath
# 53     Anima Squad     Marksman         NaN          TFT14_Xayah
# 1        Golden Ox       A.M.P.         NaN          TFT14_Annie
# 50      Divinicorp  Executioner         NaN            TFT14_Vex
# 31    Street Demon   Strategist         NaN          TFT14_Neeko
# 58       Cyberboss   Strategist         NaN          TFT14_Ziggs
# 2        Golden Ox     Marksman         NaN       TFT14_Aphelios
# 27       Syndicate       Dynamo         NaN    TFT14_MissFortune
# 26     Anima Squad     Vanguard         NaN          TFT14_Leona
# 4     Street Demon       Techie         NaN          TFT14_Brand
# 34        Overlord   Divinicorp     Bastion       TFT14_Renekton
# 37    Street Demon       A.M.P.         NaN         TFT14_Samira
# 52     Soul Killer    Golden Ox      Techie          TFT14_Viego
# 3      Anima Squad       Dynamo         NaN         TFT14_Aurora
# 55           Virus          NaN         NaN            TFT14_Zac
# 23       Cyberboss      Bruiser         NaN         TFT14_Kobuko
# 46        BoomBots  Executioner         NaN          TFT14_Urgot
# 14  God of the Net          NaN         NaN          TFT14_Garen

# %%
def count_unit_cost ( unit_list ):
    
    unit_list = [ u.replace('unit_','') for u in unit_list ]
    unit_df = get_unit_list()  
    df = unit_df[unit_df['id'].isin(unit_list)]     
    value_counts = df['cost'].stack().value_counts()
    return value_counts
